# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import gensim

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import strip_accents_unicode

import re

import nltk
from nltk.tokenize import RegexpTokenizer

from gsdmm.gsdmm import MovieGroupProcess

# %%
def holdout_text(series,train_pct = 0.9):
    '''Input : Series de dados
       Output : train,test a partir da serie de dados completamente aleatoria'''

    if(type(series) == list):
        series = pd.Series(series)
        
    num_linhas = len(series)
    series = series.sample(num_linhas)#.reset_index(drop = True)

    train_pct = train_pct

    train = series.iloc[:round(num_linhas*train_pct)]
    test = series.iloc[round(num_linhas*train_pct):]
    
    return train,test

# %% [markdown]
# #### Carregando Dataset Americanas

# %%
df = pd.read_csv("B2W-Reviews01.csv",sep = ';')

# %%
#dados de texto
text_data = df['review_text']
#text_title = df['review_title']

#stopwords
spwrds = nltk.corpus.stopwords.words('portuguese')
spwrds =[strip_accents_unicode(sw) for sw in spwrds]

def fast_preprocessing(text_data,spwrds):
    pp_text = [strip_accents_unicode(phrases) for phrases in text_data]
    pp_text = [phrases.lower() for phrases in pp_text]

    #regex_numbers 
    pp_text = [re.sub(r'\d+','<NUM>', phrases) for phrases in pp_text]

    #strip para ter certeza de espacos
    #pp_text = [phrases.strip() for phrases in pp_text]

    #tokenizacao
    rgxtoken = RegexpTokenizer('\w+')
    pp_text = [rgxtoken.tokenize(phrases) for phrases in pp_text]

    sentence = list()
    corpus = list()

    for phrases in pp_text:
        for word in phrases:
            if(word not in spwrds):
                sentence.append(word)

        corpus.append(sentence)
        sentence = list()

    pp_text = corpus
    return pp_text

# %%
train,test =  holdout_text(text_data,train_pct=0.90)

# %%
train = fast_preprocessing(train,spwrds)
test = fast_preprocessing(test,spwrds)

# %%
from gensim import corpora
from gensim import models
from gensim.models import CoherenceModel

class LDA_Modelling:
    def __init__(self, param_lda):
        
        self.param_lda = param_lda
        
        
    def train(self,text_data):
        '''Funcao que tem o objetivo de retornar o modelo lda treinado dado os parâmetros
            Input : text_data : text na forma de sentencas tokenizadas
                    param_lda : dicionário de parâmetros do LDA'''
        
        #Instancia dicitonario e cria representacao bag of words
        self.dictionary = corpora.Dictionary(text_data)
        corpus_train = [self.dictionary.doc2bow(text) for text in text_data]

        # Constroi o modelo
        self.lda_model = models.LdaModel(corpus=corpus_train ,id2word=self.dictionary,iterations=200,
                                         **self.param_lda,minimum_probability=0)

    def show_topics(self):
        print("LDA Model:")

        for idx in range(self.param_lda['num_topics']):
            # Printa os 10 tópicos mais representativos
            print("Topic #%s:" % idx, self.lda_model.print_topic(idx, 10))

            
    def transform(self,some_text):
        if(type(some_text) == str):
            bow = self.dictionary.doc2bow(some_text)
        
        else:
            bow = [self.dictionary.doc2bow(sentences) for sentences in some_text]
        
        return self.lda_model[bow]

    
    def calculate_coeherence(self,text_data):
        coherence_model_lda = CoherenceModel(model=self.lda_model,
                                             texts=text_data, dictionary=self.dictionary, coherence='c_v')
        coherence_lda = coherence_model_lda.get_coherence()
        print('\nCoherence Score: ', coherence_lda)

# %%
lda = LDA_Modelling(param_lda = {'num_topics' : 25})

# %%
lda.train(train[:1000])

# %%
lda.calculate_coeherence(train[:1000])
# Out:
# /home/saraiva/anaconda3/lib/python3.7/site-packages/scipy/sparse/lil.py:504: FutureWarning: future versions will not create a writeable array from broadcast_array. Set the writable flag explicitly to avoid this warning.
#   if not i.flags.writeable or i.dtype not in (np.int32, np.int64):
# /home/saraiva/anaconda3/lib/python3.7/site-packages/scipy/sparse/lil.py:506: FutureWarning: future versions will not create a writeable array from broadcast_array. Set the writable flag explicitly to avoid this warning.
#   if not j.flags.writeable or j.dtype not in (np.int32, np.int64):
# Coherence Score:  0.27957020466414745

# %%
transformed = lda.transform(test)

# %%
coherence_model_lda = CoherenceModel(model=self.lda_model,
                                             texts=data_lemmatized, dictionary=id2word, coherence='c_v')
        coherence_lda = coherence_model_lda.get_coherence()

# %%
topic_scores = list()
for topic in transformed:
    topic_scores.append(list(dict(topic).values()))

# %%
pd.DataFrame(topic_scores)
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.006667  0.457642  0.006667  0.006667  0.006667  0.006667  0.006667
# 1      0.004445  0.146817  0.004445  0.004445  0.004445  0.004445  0.004445
# 2      0.005001  0.005001  0.131043  0.005001  0.290070  0.005001  0.005001
# 3      0.006667  0.006667  0.006667  0.006667  0.006667  0.006667  0.006667
# 4      0.172804  0.006672  0.006672  0.006672  0.006672  0.006672  0.006672
# ...         ...       ...       ...       ...       ...       ...       ...
# 13232  0.202871  0.035873  0.001380  0.001380  0.001380  0.160505  0.001380
# 13233  0.156039  0.005715  0.005715  0.288590  0.005715  0.005715  0.005715
# 13234  0.005714  0.005714  0.005714  0.005714  0.005714  0.005714  0.005714
# 13235  0.005000  0.005000  0.005000  0.005000  0.005000  0.005000  0.005000
# 13236  0.005714  0.005714  0.005714  0.455479  0.005714  0.005714  0.005714
#
#              7         8         9   ...        15        16        17  \
# 0      0.006667  0.006667  0.006667  ...  0.006667  0.006667  0.006667
# 1      0.004445  0.004445  0.004445  ...  0.004445  0.004445  0.121237
# 2      0.468864  0.005001  0.005001  ...  0.005001  0.005001  0.005001
# 3      0.006667  0.006667  0.006667  ...  0.006667  0.006667  0.006667
# 4      0.006672  0.006672  0.006672  ...  0.006672  0.006672  0.006672
# ...         ...       ...       ...  ...       ...       ...       ...
# 13232  0.001380  0.001380  0.001380  ...  0.234850  0.039828  0.151176
# 13233  0.005715  0.287262  0.005715  ...  0.005715  0.148093  0.005715
# 13234  0.005714  0.005714  0.005714  ...  0.005714  0.005714  0.005714
# 13235  0.005000  0.005000  0.005000  ...  0.005000  0.005000  0.005000
# 13236  0.005714  0.005714  0.005714  ...  0.005714  0.005714  0.005714
#
#              18        19        20        21        22        23        24
# 0      0.006667  0.389023  0.006667  0.006667  0.006667  0.006667  0.006667
# 1      0.004445  0.004445  0.213084  0.004445  0.128878  0.004445  0.004445
# 2      0.005001  0.005001  0.005001  0.005001  0.005001  0.005001  0.005001
# 3      0.006667  0.006667  0.182570  0.006667  0.497431  0.006667  0.006667
# 4      0.006672  0.006672  0.006672  0.006672  0.465823  0.006672  0.006672
# ...         ...       ...       ...       ...       ...       ...       ...
# 13232  0.001380  0.039788  0.001380  0.001380  0.001380  0.001380  0.037492
# 13233  0.005715  0.005715  0.005715  0.005715  0.005715  0.005715  0.005715
# 13234  0.005714  0.005714  0.005714  0.278370  0.005714  0.005714  0.005714
# 13235  0.005000  0.453923  0.431076  0.005000  0.005000  0.005000  0.005000
# 13236  0.005714  0.005714  0.005714  0.413090  0.005714  0.005714  0.005714
#
# [13237 rows x 25 columns]

# %%
lda.show_topics()
# Out:
# LDA Model:
# Topic #0: 0.049*"produto" + 0.042*"qualidade" + 0.036*"foto" + 0.034*"lindo" + 0.032*"cor" + 0.026*"leve" + 0.026*"anuncio" + 0.023*"acabamento" + 0.021*"bem" + 0.021*"ficou"
# Topic #1: 0.103*"produto" + 0.095*"expectativas" + 0.066*"atendeu" + 0.054*"atende" + 0.048*"bom" + 0.044*"gostei" + 0.039*"todas" + 0.038*"necessidades" + 0.031*"superou" + 0.029*"esperava"
# Topic #2: 0.140*"facil" + 0.056*"bastante" + 0.053*"pratico" + 0.030*"bem" + 0.027*"usei" + 0.025*"obrigado" + 0.023*"gostei" + 0.022*"montar" + 0.019*"manuseio" + 0.014*"limpar"
# Topic #3: 0.048*"valor" + 0.042*"presente" + 0.039*"comprei" + 0.036*"tanto" + 0.036*"frete" + 0.033*"filho" + 0.027*"adorou" + 0.023*"r" + 0.021*"p" + 0.020*"unica"
# Topic #4: 0.153*"americanas" + 0.070*"sempre" + 0.060*"parabens" + 0.056*"lojas" + 0.052*"entrega" + 0.047*"produtos" + 0.042*"loja" + 0.022*"compro" + 0.021*"comprar" + 0.015*"expectativa"
# Topic #5: 0.042*"uso" + 0.037*"marca" + 0.035*"comprei" + 0.024*"pra" + 0.022*"celular" + 0.017*"dois" + 0.016*"outro" + 0.016*"menos" + 0.014*"aparelho" + 0.014*"outra"
# Topic #6: 0.044*"livro" + 0.039*"caixa" + 0.032*"veio" + 0.031*"acho" + 0.031*"deixa" + 0.030*"desejar" + 0.023*"deveria" + 0.019*"peca" + 0.018*"sobre" + 0.017*"horrivel"
# Topic #7: 0.055*"pra" + 0.046*"q" + 0.030*"nada" + 0.015*"reclamar" + 0.014*"ta" + 0.013*"falar" + 0.013*"pq" + 0.013*"vai" + 0.011*"dizer" + 0.011*"propaganda"
# Topic #8: 0.129*"produto" + 0.102*"recomendo" + 0.076*"qualidade" + 0.072*"entrega" + 0.067*"super" + 0.064*"excelente" + 0.052*"rapida" + 0.040*"otima" + 0.039*"bom" + 0.033*"otimo"
# Topic #9: 0.107*"bom" + 0.063*"tv" + 0.052*"boa" + 0.052*"pena" + 0.046*"vale" + 0.043*"imagem" + 0.041*"bateria" + 0.034*"som" + 0.029*"preco" + 0.023*"celular"
# Topic #10: 0.032*"relogio" + 0.028*"util" + 0.025*"tao" + 0.025*"fone" + 0.020*"vida" + 0.020*"notebook" + 0.015*"impressao" + 0.014*"todo" + 0.013*"preto" + 0.012*"quebrou"
# Topic #11: 0.036*"produto" + 0.029*"saber" + 0.028*"gostaria" + 0.027*"veio" + 0.025*"pecas" + 0.022*"embalagem" + 0.021*"porem" + 0.013*"duas" + 0.013*"demora" + 0.013*"cheiro"
# Topic #12: 0.137*"prazo" + 0.116*"chegou" + 0.109*"antes" + 0.094*"produto" + 0.061*"entrega" + 0.040*"bem" + 0.034*"recomendo" + 0.033*"bom" + 0.032*"dentro" + 0.020*"entregue"
# Topic #13: 0.096*"produto" + 0.052*"recebi" + 0.035*"ainda" + 0.024*"americanas" + 0.019*"compra" + 0.018*"comprei" + 0.018*"contato" + 0.017*"site" + 0.016*"avaliar" + 0.015*"agora"
# Topic #14: 0.055*"custo" + 0.054*"otimo" + 0.052*"bom" + 0.051*"beneficio" + 0.049*"produto" + 0.031*"bem" + 0.030*"ser" + 0.025*"tamanho" + 0.025*"excelente" + 0.024*"melhor"
# Topic #15: 0.051*"parece" + 0.041*"fragil" + 0.033*"pratica" + 0.031*"ser" + 0.030*"manual" + 0.028*"ver" + 0.027*"plastico" + 0.021*"limpeza" + 0.019*"audio" + 0.018*"bebe"
# Topic #16: 0.038*"memoria" + 0.023*"novamente" + 0.023*"cartao" + 0.021*"modelo" + 0.021*"boas" + 0.020*"processador" + 0.020*"kit" + 0.020*"funcao" + 0.018*"cores" + 0.018*"compraria"
# Topic #17: 0.045*"produto" + 0.042*"troca" + 0.041*"veio" + 0.041*"problema" + 0.039*"defeito" + 0.029*"vez" + 0.027*"nenhum" + 0.026*"primeira" + 0.022*"dinheiro" + 0.017*"quero"
# Topic #18: 0.041*"ter" + 0.036*"comprar" + 0.030*"fazer" + 0.026*"vou" + 0.020*"pessoas" + 0.020*"caro" + 0.019*"consigo" + 0.016*"pra" + 0.015*"comprado" + 0.014*"produto"
# Topic #19: 0.095*"funciona" + 0.075*"bem" + 0.044*"perfeitamente" + 0.031*"linda" + 0.031*"filha" + 0.030*"maquina" + 0.030*"confortavel" + 0.028*"cabelo" + 0.026*"desempenho" + 0.024*"funcionando"
# Topic #20: 0.052*"original" + 0.019*"perfume" + 0.016*"necessidade" + 0.016*"mto" + 0.016*"acredito" + 0.014*"disse" + 0.013*"produto" + 0.013*"estorno" + 0.012*"filtro" + 0.012*"enviaram"
# Topic #21: 0.037*"agua" + 0.030*"pode" + 0.020*"faz" + 0.019*"qualquer" + 0.018*"colocar" + 0.016*"ser" + 0.015*"fica" + 0.014*"sistema" + 0.013*"possui" + 0.013*"esquenta"
# Topic #22: 0.331*"NUM" + 0.053*"dia" + 0.035*"dias" + 0.019*"comprei" + 0.014*"nota" + 0.013*"entrega" + 0.011*"produto" + 0.011*"chegar" + 0.009*"hoje" + 0.008*"compra"
# Topic #23: 0.068*"aparelho" + 0.030*"tela" + 0.030*"celular" + 0.024*"camera" + 0.023*"cabo" + 0.022*"grande" + 0.021*"toda" + 0.019*"espaco" + 0.019*"trava" + 0.017*"hora"
# Topic #24: 0.052*"maravilhoso" + 0.045*"demais" + 0.043*"controle" + 0.036*"condicoes" + 0.033*"ponto" + 0.032*"unico" + 0.027*"gosto" + 0.025*"funcionou" + 0.024*"fraco" + 0.022*"potente"

# %%
# %%time
from gensim import models, corpora
NUM_TOPICS = 50
dictionary = corpora.Dictionary(train)

corpus_train = [dictionary.doc2bow(text) for text in train]
 
# Build the LDA model
lda_model = models.LdaModel(corpus=corpus_train, num_topics=NUM_TOPICS, id2word=dictionary,iterations=200)
 
# Build the LSI model
#lsi_model = models.LsiModel(corpus=corpus_train, num_topics=NUM_TOPICS, id2word=dictionary)
# Out:
# CPU times: user 1min 1s, sys: 1.12 s, total: 1min 3s
# Wall time: 1min 1s

# %%
bow = dictionary.doc2bow(test.reset_index(drop = True)[0])
 
#print(lsi_model[bow])
 
print(lda_model[bow])
# Out:
# [(0, 0.13416106), (22, 0.16999689), (29, 0.16933051), (45, 0.37317678)]

# %%
print("LDA Model:")
 
for idx in range(NUM_TOPICS):
    # Print the first 10 most representative topics
    print("Topic #%s:" % idx, lda_model.print_topic(idx, 10))
 
print("=" * 20)
 
# print("LSI Model:")
 
# for idx in range(NUM_TOPICS):
#     # Print the first 10 most representative topics
#     print("Topic #%s:" % idx, lsi_model.print_topic(idx, 10))
 
# print("=" * 20)
# Out:
# LDA Model:
# Topic #0: 0.056*"ninguem" + 0.053*"barato" + 0.029*"pior" + 0.028*"atraso" + 0.026*"porcaria" + 0.024*"passou" + 0.024*"absurdo" + 0.024*"faco" + 0.024*"diferenca" + 0.023*"telefone"
# Topic #1: 0.076*"foto" + 0.071*"cor" + 0.067*"outro" + 0.054*"modelo" + 0.052*"diferente" + 0.039*"veio" + 0.037*"comprei" + 0.037*"igual" + 0.036*"produto" + 0.034*"totalmente"
# Topic #2: 0.084*"jogo" + 0.074*"valor" + 0.058*"pequeno" + 0.057*"preco" + 0.039*"servico" + 0.039*"frete" + 0.038*"esquenta" + 0.035*"caro" + 0.031*"principalmente" + 0.029*"jogos"
# Topic #3: 0.104*"pena" + 0.099*"vale" + 0.067*"todas" + 0.066*"imagem" + 0.053*"som" + 0.041*"linda" + 0.039*"top" + 0.035*"filha" + 0.032*"valeu" + 0.032*"perfeita"
# Topic #4: 0.110*"cumpre" + 0.098*"realmente" + 0.085*"promete" + 0.042*"funcao" + 0.040*"produto" + 0.032*"processador" + 0.030*"moderno" + 0.028*"bem" + 0.028*"funcoes" + 0.027*"consegue"
# Topic #5: 0.184*"prazo" + 0.128*"antes" + 0.111*"chegou" + 0.108*"produto" + 0.071*"entrega" + 0.047*"recomendo" + 0.045*"dentro" + 0.034*"bom" + 0.031*"bem" + 0.025*"entregue"
# Topic #6: 0.147*"tudo" + 0.094*"perfeito" + 0.093*"rapido" + 0.079*"chegou" + 0.062*"produto" + 0.050*"recomendo" + 0.045*"bom" + 0.040*"estado" + 0.037*"certo" + 0.035*"atendimento"
# Topic #7: 0.052*"meses" + 0.042*"simplesmente" + 0.033*"uso" + 0.032*"garantia" + 0.028*"funcionar" + 0.028*"ano" + 0.028*"funcionando" + 0.028*"NUM" + 0.025*"apos" + 0.022*"tempo"
# Topic #8: 0.094*"problema" + 0.079*"dois" + 0.072*"nenhum" + 0.063*"deu" + 0.060*"quase" + 0.029*"maravilhosa" + 0.028*"uns" + 0.027*"tapete" + 0.025*"dias" + 0.024*"lento"
# Topic #9: 0.135*"ser" + 0.082*"ter" + 0.040*"poderia" + 0.039*"melhor" + 0.034*"deveria" + 0.031*"apesar" + 0.030*"parte" + 0.028*"pouco" + 0.021*"outros" + 0.019*"alto"
# Topic #10: 0.119*"aparelho" + 0.114*"celular" + 0.065*"bateria" + 0.047*"camera" + 0.036*"tela" + 0.035*"bom" + 0.029*"boa" + 0.027*"rapido" + 0.026*"memoria" + 0.026*"trava"
# Topic #11: 0.071*"quanto" + 0.061*"muita" + 0.056*"tanto" + 0.049*"baixo" + 0.043*"x" + 0.037*"smartphone" + 0.036*"samsung" + 0.032*"potencia" + 0.028*"alta" + 0.028*"lg"
# Topic #12: 0.221*"entrega" + 0.131*"rapida" + 0.116*"super" + 0.085*"produto" + 0.069*"parabens" + 0.048*"adorei" + 0.044*"americanas" + 0.038*"bem" + 0.032*"embalado" + 0.031*"excelente"
# Topic #13: 0.098*"fiquei" + 0.095*"satisfeita" + 0.095*"produtos" + 0.082*"satisfeito" + 0.074*"produto" + 0.036*"compra" + 0.029*"propaganda" + 0.026*"suporte" + 0.026*"anunciado" + 0.022*"decepcionada"
# Topic #14: 0.209*"otimo" + 0.146*"bom" + 0.126*"custo" + 0.113*"beneficio" + 0.104*"produto" + 0.046*"recomendo" + 0.029*"excelente" + 0.020*"feliz" + 0.015*"gostei" + 0.010*"mae"
# Topic #15: 0.115*"bonito" + 0.093*"atende" + 0.085*"material" + 0.058*"necessidades" + 0.052*"bem" + 0.035*"bom" + 0.034*"bonita" + 0.034*"ruim" + 0.033*"produto" + 0.028*"montar"
# Topic #16: 0.069*"comprem" + 0.039*"informacoes" + 0.031*"direito" + 0.028*"brasil" + 0.026*"nesse" + 0.024*"leitura" + 0.023*"digital" + 0.023*"android" + 0.020*"remoto" + 0.019*"favor"
# Topic #17: 0.052*"hd" + 0.027*"video" + 0.023*"seguranca" + 0.023*"roda" + 0.022*"onde" + 0.018*"tentar" + 0.018*"metade" + 0.018*"quebrada" + 0.016*"computador" + 0.015*"acabado"
# Topic #18: 0.055*"chegar" + 0.052*"produto" + 0.049*"demorou" + 0.046*"condicoes" + 0.042*"certeza" + 0.033*"devido" + 0.031*"estar" + 0.026*"perfeitas" + 0.025*"logo" + 0.022*"sido"
# Topic #19: 0.073*"unico" + 0.066*"ponto" + 0.062*"dificil" + 0.049*"compro" + 0.032*"processo" + 0.028*"temperatura" + 0.028*"negativo" + 0.028*"problema" + 0.026*"local" + 0.024*"att"
# Topic #20: 0.119*"faz" + 0.099*"livro" + 0.046*"p" + 0.034*"barulho" + 0.028*"d" + 0.023*"inferior" + 0.023*"claro" + 0.021*"fez" + 0.021*"velocidade" + 0.020*"pouco"
# Topic #21: 0.150*"veio" + 0.046*"caixa" + 0.041*"produto" + 0.039*"pecas" + 0.036*"pessima" + 0.031*"vez" + 0.028*"primeira" + 0.028*"porem" + 0.022*"peca" + 0.020*"cuidado"
# Topic #22: 0.049*"meio" + 0.044*"pequena" + 0.041*"smart" + 0.033*"resultado" + 0.033*"crianca" + 0.032*"preco" + 0.031*"aquisicao" + 0.031*"linha" + 0.030*"la" + 0.029*"carro"
# Topic #23: 0.081*"agora" + 0.071*"sobre" + 0.053*"nenhuma" + 0.037*"nada" + 0.032*"resposta" + 0.032*"reclamacao" + 0.030*"pois" + 0.027*"avaliacao" + 0.026*"mercadoria" + 0.025*"tentei"
# Topic #24: 0.046*"lo" + 0.045*"horrivel" + 0.043*"cafe" + 0.032*"informacao" + 0.031*"fica" + 0.027*"menor" + 0.025*"ficam" + 0.025*"recomendado" + 0.025*"usa" + 0.022*"configuracao"
# Topic #25: 0.069*"produto" + 0.057*"americanas" + 0.029*"loja" + 0.026*"site" + 0.025*"contato" + 0.021*"empresa" + 0.021*"recebi" + 0.020*"comprei" + 0.017*"nunca" + 0.017*"nada"
# Topic #26: 0.069*"produto" + 0.066*"acabamento" + 0.065*"conforme" + 0.053*"descricao" + 0.048*"vendedor" + 0.044*"diz" + 0.037*"aguardando" + 0.033*"acordo" + 0.032*"deixou" + 0.029*"falar"
# Topic #27: 0.100*"parece" + 0.078*"simples" + 0.056*"ver" + 0.048*"cabo" + 0.046*"vai" + 0.039*"bem" + 0.037*"ser" + 0.031*"funcional" + 0.030*"mal" + 0.029*"tbm"
# Topic #28: 0.091*"funciona" + 0.091*"bem" + 0.077*"usar" + 0.065*"lindo" + 0.053*"perfeitamente" + 0.043*"resistente" + 0.039*"facil" + 0.025*"recomendo" + 0.023*"super" + 0.023*"opcao"
# Topic #29: 0.068*"demora" + 0.067*"acho" + 0.052*"relacao" + 0.051*"falta" + 0.043*"relogio" + 0.037*"chega" + 0.034*"consumidor" + 0.031*"produto" + 0.030*"transportadora" + 0.025*"respeito"
# Topic #30: 0.139*"comprar" + 0.089*"q" + 0.051*"vou" + 0.047*"pode" + 0.030*"pq" + 0.028*"vcs" + 0.025*"n" + 0.021*"espero" + 0.019*"pra" + 0.018*"produto"
# Topic #31: 0.062*"porque" + 0.050*"cabelo" + 0.045*"usei" + 0.043*"vezes" + 0.041*"queria" + 0.040*"varias" + 0.038*"preciso" + 0.031*"devolver" + 0.030*"pro" + 0.026*"fazer"
# Topic #32: 0.190*"qualidade" + 0.151*"produto" + 0.125*"recomendo" + 0.094*"excelente" + 0.087*"otima" + 0.055*"boa" + 0.041*"bom" + 0.036*"todos" + 0.032*"super" + 0.030*"gostei"
# Topic #33: 0.123*"facil" + 0.085*"pratico" + 0.066*"agua" + 0.046*"produto" + 0.042*"leve" + 0.039*"bom" + 0.031*"maquina" + 0.030*"instalacao" + 0.030*"recomendo" + 0.026*"espaco"
# Topic #34: 0.098*"original" + 0.084*"anuncio" + 0.051*"produto" + 0.047*"infelizmente" + 0.044*"certinho" + 0.039*"tipo" + 0.039*"dizer" + 0.036*"mercado" + 0.032*"perfume" + 0.031*"cheiro"
# Topic #35: 0.136*"expectativas" + 0.117*"atendeu" + 0.074*"vem" + 0.073*"produto" + 0.043*"gostaria" + 0.036*"saber" + 0.033*"embalagem" + 0.032*"design" + 0.030*"notebook" + 0.028*"bom"
# Topic #36: 0.082*"presente" + 0.053*"coisa" + 0.043*"dar" + 0.035*"aqui" + 0.030*"unica" + 0.027*"boa" + 0.026*"primeiro" + 0.025*"tecnica" + 0.025*"americana" + 0.025*"caso"
# Topic #37: 0.085*"deixa" + 0.061*"alguns" + 0.049*"desejar" + 0.044*"util" + 0.039*"forma" + 0.032*"colocar" + 0.032*"muitos" + 0.029*"enfim" + 0.028*"completo" + 0.027*"novamente"
# Topic #38: 0.127*"sempre" + 0.112*"marca" + 0.077*"grande" + 0.077*"indico" + 0.043*"possui" + 0.032*"fone" + 0.027*"vieram" + 0.023*"contar" + 0.022*"cabe" + 0.020*"gostou"
# Topic #39: 0.181*"ainda" + 0.170*"produto" + 0.159*"recebi" + 0.058*"avaliar" + 0.050*"nota" + 0.039*"posso" + 0.023*"fiscal" + 0.020*"ta" + 0.018*"momento" + 0.017*"chegou"
# Topic #40: 0.138*"compra" + 0.052*"fiz" + 0.044*"pedido" + 0.037*"paguei" + 0.020*"pagamento" + 0.020*"site" + 0.019*"reais" + 0.017*"r" + 0.015*"nessa" + 0.015*"ai"
# Topic #41: 0.061*"duas" + 0.046*"outra" + 0.041*"manual" + 0.039*"varios" + 0.033*"precisa" + 0.030*"deste" + 0.030*"pessoa" + 0.029*"melhores" + 0.028*"clientes" + 0.023*"mandaram"
# Topic #42: 0.081*"pra" + 0.049*"dinheiro" + 0.047*"mim" + 0.044*"hora" + 0.041*"filho" + 0.039*"sim" + 0.034*"comprei" + 0.033*"toda" + 0.033*"volta" + 0.031*"quero"
# Topic #43: 0.123*"dia" + 0.116*"uso" + 0.080*"casa" + 0.038*"quer" + 0.026*"ideal" + 0.026*"pra" + 0.023*"serve" + 0.022*"kit" + 0.020*"ajuda" + 0.018*"bom"
# Topic #44: 0.171*"achei" + 0.124*"tamanho" + 0.089*"esperava" + 0.081*"maravilhoso" + 0.040*"bom" + 0.035*"produto" + 0.035*"mto" + 0.031*"mesa" + 0.028*"gostei" + 0.024*"melhor"
# Topic #45: 0.071*"demais" + 0.048*"esperando" + 0.042*"s" + 0.037*"g" + 0.035*"fornecedor" + 0.032*"criancas" + 0.031*"verdade" + 0.028*"moto" + 0.026*"to" + 0.024*"luz"
# Topic #46: 0.123*"ficou" + 0.052*"maior" + 0.049*"desse" + 0.037*"impressora" + 0.036*"novo" + 0.026*"estoque" + 0.025*"base" + 0.024*"compativel" + 0.022*"comecou" + 0.022*"testei"
# Topic #47: 0.109*"data" + 0.105*"americanas" + 0.092*"lojas" + 0.053*"produto" + 0.045*"reclamar" + 0.044*"prevista" + 0.042*"antes" + 0.038*"chegou" + 0.030*"esperado" + 0.027*"panelas"
# Topic #48: 0.089*"tv" + 0.072*"defeito" + 0.044*"veio" + 0.037*"troca" + 0.028*"controle" + 0.028*"imagem" + 0.022*"consigo" + 0.022*"consegui" + 0.022*"trocar" + 0.019*"ligar"
# Topic #49: 0.543*"NUM" + 0.061*"dias" + 0.060*"dia" + 0.030*"comprei" + 0.024*"entrega" + 0.022*"hoje" + 0.012*"produto" + 0.011*"agora" + 0.009*"chegou" + 0.008*"uteis"
# ====================

# %%
# %%time
tfidf = TfidfVectorizer(stop_words = spwrds,min_df = 10)
tfidf.fit(train)

#train = tfidf.transform(train)
#test = tfidf.transform(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit(self, raw_documents, y)
#    1629         """
#    1630         self._check_params()
# -> 1631         X = super().fit_transform(raw_documents)
#    1632         self._tfidf.fit(X)
#    1633         return self
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1056
#    1057         vocabulary, X = self._count_vocab(raw_documents,
# -> 1058                                           self.fixed_vocabulary_)
#    1059
#    1060         if self.binary:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     968         for doc in raw_documents:
#     969             feature_counter = {}
# --> 970             for feature in analyze(doc):
#     971                 try:
#     972                     feature_idx = vocabulary[feature]
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     350                                                tokenize)
#     351             return lambda doc: self._word_ngrams(
# --> 352                 tokenize(preprocess(self.decode(doc))), stop_words)
#     353
#     354         else:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in <lambda>(x)
#     254
#     255         if self.lowercase:
# --> 256             return lambda x: strip_accents(x.lower())
#     257         else:
#     258             return strip_accents
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
mgp = MovieGroupProcess(K=100, alpha=0.1, beta=0.5, n_iters=20)

mgp.fit([[elements] for elements in train][:1000],
        len(tfidf.vocabulary_.keys()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-7acced72c486> in <module>
#       2
#       3 mgp.fit([[elements] for elements in train][:1000],
# ----> 4         len(tfidf.vocabulary_.keys()))
#
# AttributeError: 'TfidfVectorizer' object has no attribute 'vocabulary_'

# %%
doc_count = np.array(mgp.cluster_doc_count)
print('Number of documents per topic :', doc_count)
print('*'*20)
# Topics sorted by the number of document they are allocated to
top_index = doc_count.argsort()[-10:][::-1]
print('Most important clusters (by number of docs inside):', top_index)
print('*'*20)
# Show the top 5 words in term frequency for each cluster 
top_words(mgp.cluster_word_distribution, top_index, 5)

# %%
mgp.cluster_word_distribution
# Out:
# [{'comprei ele, gastei com chip, recarga e nao funcionou. fica com a luz acesa e nao reconhece o chip. ligo e so da na caixa postal. nao funciona. decepcionado.': 1,
#   'produto e bom, mas nao se engane achando que seja um ar condicionado': 1,
#   'pela imagem ilustrativa achei que viria junto com o painel na embalagem, o suporte pra tv ate <NUM> polegadas! na minha opiniao em geral seria o correto esse item !': 1,
#   'o produto nao reconheceu o chip. quanto as funcoes alguns funciona normalmente e outros nao.': 1,
#   'embora tenha utilizado muito pouco, mas me parece ser um otimo produto. a entrega foi rapida. chegou tudo certinho. recomendo.': 1,
#   'eu nao recebi meu produto.como voces querem que eu avalie minha compras.': 1,
#   'excelente! eu recomendo!obrigado!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!': 1,
#   'nao foi entregue minha mercadoria ,faz mais de trinta dias que estou esperando': 1,
#   'a imagem para os canais e boa, mas para jogos e filmes on line e muito ruim. os graficos dos jogos perderam muita qualidade de imagem (nitidez), bem como os filmes on line (netflix).': 1,
#   'sandalia confortavel porem a parte da frente nao e duravel...': 1,
#   'acreditava que o produto era de melhor qualidade, porem, as sombras esfarelam muito, a pigmentacao nao e la essas maravilhas. e piora quando uso o primer para sombras. produto bem mediano.': 1,
#   'ficou grande, gostaria de trocar pelo numero <NUM> e na cor branca': 1},
#  {},
#  {},
#  {'eu ja possuia um note <NUM> da samsung, ele ja estava um pouco lento quando eu acessava  a internet , este porem e bem mais rapido, muito bom': 1,
#   'otimo produto, ja e o segundo que comprei. o primeiro ja tenho a anos e comprei outro, so para ter um zero km.': 1,
#   'o relogio e muito bonito, o tamanho e ideal, recomento a compra': 1,
#   'comprei <NUM> pra utilizar no motor rossi nao e compativel': 1,
#   'as bonecas sao lindas chegou antes da data americana como sempre mim surpreender!': 1,
#   'otimo cd.! musicas antigas no estilo alex gonzaga. recomendavel.': 1,
#   'alcance de volume muito bom. a unica  coisa que nao gostei muito, e que so fala em ingles, entao algumas vezes ou para algumas pessoas pode ser ruim, por nao entender as instrucoes ditas. mas mesmo assim consegui usar numa boa hehe': 1,
#   'produto cumpre o que promete. muito facil de usar e com excelente qualidade.': 1,
#   'telefone muito bom com otima camera tanto frontal quanto principal, excelente sistema operacional......super satisfeito.': 1,
#   'a colcha e totalmente diferente da foto, a capa do travesseiro e pessimo, quase transparente, enfim ja solicitei a devolucao!': 1,
#   'coloquei no quintal para iluminar a escada para evitar acidentes. ilumina bem.': 1,
#   'os potes sao de qualidades, mas propaganda enganosa,meles sao micro , nao cabem nada!': 1,
#   'gostei muito do produto e a cor e linda! o produto chegou dentro do prazo para a entrega.': 1,
#   'como vcs querem q eu avalie um produto q vcs ainda nao me entregaram?': 1,
#   'quem gosta de iron maiden nao deixaria de gostar!  iron sempre bom e vale a pena curtir uma coletanea.': 1,
#   'com exatos <NUM> dias de uso, o produto veio a apresentar problema, onde apareceu uma mensagem informando "bateria invalida" e logo em seguida o celular desligava, o que impossibilita o seu uso.': 1,
#   'ainda estou descobrindo algumas coisas, mas de inicio gostei muito...': 1,
#   'chegou antes do prazo, facil de montar, tudo de bom, recomendo.': 1,
#   'nao comprem nao tem garantia no brasil, comprei e estou com problema, e foi aqui pelo site da americanas.': 1,
#   'excelente celular, se quiser economia de bateria e so desligar a leitura da digital': 1,
#   'produto muito bom  chegou  antes do prazo recomendo tanto o produto quantos a empresa': 1,
#   'produto de otima qualidade. recomendo a todos. entrega no prazo determinado': 1,
#   'recomendo pata todos os meus amigos, conhecerem as lojas americanas.': 1},
#  {},
#  {'adoramos o produto... os equipamentos excelentes para quem esta com seu primeiro patins... super recomendo!!! a unica coisa que descobrimos e que o bumbum faltou ser protegido kkk... vai ai uma sugestao: precisam de pensar em um equipamento de protecao para o bumbum.  bjus obrigadaaaa': 1,
#   'comprei este produto com a intencao de conseguir fatiadas das mais diversas espessuras e a lamina plana que vem no kit e extremamente grossa. os ralos da feira ralam a batata mais fino que este mandolin. odiei.': 1,
#   'o aparelho durou apenas <NUM> meses. sem uso intenso. esperava mais um pouco. pelo menos <NUM> ano.': 1,
#   'o melhor livro da serie as quatro estacoes, nao consegui deixar o livro ate chegar a ultima pagina. lindo.': 1,
#   'um produto maravilhoso! por que nao comprei antes, acabei comprando o mop twitter turbo, que e um pouco maior e absorve muito, tambem.  na duvida, leve os dois.': 1},
#  {'e pratico, moderno, lindo! tamanho ideal para uma grande familia! otimo!': 1,
#   'alem do design futuristico, tambem tem uma tecnologia que tornou o valor um investimento, e nao um gasto! "samsung - creative technologie"': 1,
#   'instalacao simples e funcional, porem, passivel dos mesmos problemas de sinal como qualquer outro dispositivo gsm, mas funciona!': 1,
#   'funcionamento otimo, nao faz tanto barulho, recomendo ele p todos': 1,
#   'qual a medida ????   voces tem que por tal informacao....': 1,
#   'celular que supre minhas necessidades do dia a dia. tem um bom acabamento.': 1,
#   'rapida, pratica e simples de trabalhar.recomendo o produtos. e a entrega bem antes do previsto. parabens.': 1,
#   'muito lindo o papel, super recomendo, chegou em <NUM> dias bem antes do previsto.': 1,
#   'gostei veio igual a imagem  recomendo para as pessoas': 1,
#   'ate hoje nao recebi o produto. era para ter chegado dia <NUM>/<NUM>/<NUM>. pessimo servico de entrega. nao recomendo': 1,
#   'otimo som, imagem, interacao da opcao smart excelente. integracao com smartphone um pouco lenta mas isso obviamente depende da conexao. em suma otimo produto pra quem tem sala pequena.': 1,
#   'o produto nao chegou......ja faz mais de <NUM> dias. onde esta, quem e responsavel por garantir que chegue ao destino? uma vergonha...': 1,
#   'embora o produto seja de qualidade a cor nao condiz com a foto e o projeto esta totalmente errado, as medidas do manual nao da nada certo. tivemos muito trabalho pra montar. por este motivo nao recomendo': 1,
#   'muito bom o produto, muito util, com certeza recomendo': 1,
#   'comprei este ventilador na voltagem <NUM>v e acabou vindo <NUM>v. tive que fazer alteracoes na instalacao d minha casa. ele tem bastante velocidade, porem nao faz tanto vento.  nao sei se e pelo tamanho e largura da elice. mais recomendo sim. pelo preco e pela marca que e bem conceituada.': 1,
#   'mt bom otimo preco entrega rapida maravilhosa. otimo  gostei': 1,
#   'a montagem e possivel com apenas uma pessoal, produto de qualidade e quando desmontada ocupa pouco espaco. mais pratica que ela so a articulavel, porem ocupa muito espaco.': 1,
#   'otimo produto e chegou antes do prazo previsto, realizei instalacao do mesmo e esta em perfeito estado de uso, muito satisfeito com a compra. recomendo para quem esta a procura de um som simples e esta sem muita grana para investir, fica com um otimo com ambiente para seu carro.': 1,
#   'gostei muito do produto .recomendo a loja americana pois tem sempre otimas ofertas.': 1,
#   'o produto e bom, igual ao descrito no site, porem acredito que poderia ter melhoras significativas no acabamento sem ter aumento de custos repassados ao consumidor final.': 1,
#   'entrega e prazo perfeito. recomendo vale a compra.': 1,
#   'produto original passou nos testes, estou satisfeito chegou super rapido': 1,
#   'eu estava prestes a ser demitido ,mas tive a ideia de presentear meu chefe com essa tv ,saquei meu fgts e peguei o restante na crefisa ,ele ficou muito satisfeito e disse que assim que as coisas melhorarem vai me chamar de volta .': 1,
#   'pratico simples de instalar funciona bem. um otimo produto para uso domestico.': 1,
#   'estou pagando o produto que nem se quer chegou mais de <NUM> meses pra chegar muita demora': 1,
#   'produto entregue dentro do prazo, otima qualidade e conforto. vale a pena comprar. super recomendo.': 1,
#   'e um sofa muito bonito , confortavel atendendo minhas necessidades.': 1,
#   'apesar de ter gostado do produto quanto a qualidade e manuseio, acho que poderia ser mais leve e mais fino.': 1,
#   'valeu a pena, um aparelho que atende perfeitamente as necessidades em geral com a camera frontal muito boa. a entrega da americanas sempre antes do previsto!!': 1,
#   'amei tudo!  e tambem e mais em conta do que na loja fisica.': 1,
#   'o produto esta atendendo minha expecitativas nao tive problema quanto ao prazo de entrega': 1,
#   'produto excelente, recomendo muito para as pessoas que estao com duvidas! entrega rapida....': 1,
#   'nao recebi o produto, fica complicado para avaliar!! poderiam verificar o que esta acontecendo!!': 1,
#   'o liquidificador e muito bom tem uma potencia mais do que eu esperava e e muito bonito.': 1,
#   'liguei p/ a.a.da silva  mi falaram que so funciona no ford ka acima de <NUM> ,o meu e <NUM> mas o catalogo da ford o meu e obd<NUM>,assim mesmo experimentei num fiesta <NUM> tambem nao funcionou ,agora fica complicado trocar ,amanha (<NUM>/<NUM>/<NUM> ) vou tornar a ligar p/ a.a.da silva p/ ver o que resolvemos...': 1,
#   'o produto e de otima qualidade. porem, o fornecedor enegou o produto errado. comprei o lipo <NUM> black <NUM> capsulas e recebi o produto com <NUM> capsulas. estou tendo a maior dor de cabeca para resolver.': 1,
#   'comprei o travesseiro e e um bom produto. a entrega pela arrumadinho enxovais foi pessima: o travesseiro chegou embalado apenas naquele plastico de encomendas. ou seja, foi amassado por outras cargas em todos os trajetos. alem de falta de higiene, deve ter danificado o produto. nao recomendo esta empresa para comprar travesseiros!': 1,
#   'muito fragil. a helice estava torta. dificil fazer voar. nao recomendo.': 1,
#   'o produto me atende satisfatoriamente. na primeira utilizacao, a agua apresentou gosto de plastico, mas desapareceu a partir do segundo galao.': 1,
#   'entrega no prazo, veio bem embalado, otima qualidade!': 1},
#  {'ruim de instalar material de ma qualidade  desbota nas extremidades onde tem contato e nao cumpre conforme  propaganda... a estetica de longe fica apresentavel mas na aplicacoes dao bolhas e se faz necessario ajustar para o tamanho de cada item...nao recomendado': 1,
#   'pra quem quer um intermediario premium,recomendo. iria comprar o moto z play, mas aida bem que desistir a tempo. otimo custo beneficio. produto entregue no prazo certo.': 1,
#   'nao recebi o produto inteiro fiz a reclamacao por email que nao foi considerada quando tive temoo de ir em uma loja americanas que formalizou a reclamacao dizendo que solucionaria o problema dias depois recebo um email do fabricante dizendo que nao pode trocar pq passou dos <NUM> dias. dizendo que iriam entrar em contato e ate hoje tem que ter paciencia viu': 1,
#   'o produto e excelente, o atendimento das lojas americanas tambem e muito bom': 1,
#   'como arquiteta uso em todo lugar. atencao, nao serve para medidas pequenas.': 1,
#   'ate agora, nao chegou.nao chegou.nao chegou. nao chegou.nao chegou.nao chegou.': 1,
#   'destestei nao foi enviado o que esta na foto do produto.': 1,
#   'nao esquenta na potencia que realmente falam. se u soubesse teria adquirido outro produto': 1,
#   'achei que os potes muito pequenos mas e de boa qualidade.': 1,
#   'mas a entrega de voces da americanas, ta muito ruim, no mesmo dia que eu comprei esse smartphone com voces, eu comprei no magazine luiza um carrinho de espetinhos que pesa <NUM> kg uma embalagem enorme vinda de sao paulo e chegou aqui no meu cep com <NUM> dias uteis, agora um smartphone demorou demais, ate hoje nao recebi, e mais no dia <NUM> eu consegui rastrear a transportadora ate contagem de la para ca nao tenho mais noticias, muito ruim a entrega americanas.': 1,
#   'muito bom mesmo e excelente valeu a pena dar esse presente para meu filho nota <NUM>': 1,
#   'perfeito  entrega feita no endereco fornecido. estourar satisfeita.': 1,
#   'americanas te que se responder pq vendem um produto e entregam outro': 1,
#   'uma versao bastante interessante, pois traz um ponto de vista e estrategia bem diversificados. gostei muito.': 1,
#   'faz duas semanas que estou tomando. ja notei as unhas  mais duras.': 1,
#   'esse preco e absurdo , um abuso . com o valor que pago nele faco varias cestas.': 1,
#   'muito bom. estou adorando. nao vdescarrega rapido, mesmo com muitos aplicativos aberto, em uso, o snap e um acessorio eficiente, eu concerteza recomendo moto z<NUM> para quem gosta do que e bom.': 1,
#   'produto perfeito, melhor do que eu esperava, gostei muito da “canetinh” que veio como acessorio, super recomendo.': 1,
#   'eu amei a minha tv!  superou minhas expectativas, a samsung como sempre esta  de parabens! e a americanas como sempre a minha queridinha da internet! chegou bem antes  do prazo, como tudo que compro no site!': 1,
#   'essa escova e maravilhosa!! pra mim ela e a melhor do mercado nacional, o bom e q ela nao e rotativa, eu mesma tenho o controle dos movimentos, nao corre o risco de enroscar. e ela e bem potente, seca muito rapido e alisa muito bem meu cabelo ondulado e volumoso': 1,
#   'no titulo da avaliacao, ja diz, a tramontina; faz produtos de qualidade, para atender todos niveis de consumidores.': 1,
#   'pensei q era um pouco maior e na descricao nao diz tamanho.': 1},
#  {},
#  {},
#  {},
#  {},
#  {'gostei muito do produto!cumpre o prometido!pratica, facil  de manusear , de guardar e usar!e o custo beneficio excelente!!recomendo !!estou pensando em comprar outra pra deixar na fazenda!!': 1,
#   'adorei o produto e amei a rapidez da entrega! loja americanas arrasa!': 1,
#   'a tv e linda , fina , volume maravilhoso , super rapida , entregaram como sempre <NUM> dias antes do prazo , isso que moro no mt , americanas sempre a melhor loja . amei minha super tv <<NUM>': 1,
#   'tive dois problema recorrentes no primeiro recebi o produto errado (ou trocado) sendo a placa v<NUM> sendo codigo <NUM> entrei em contato de imediato com o vendedor recorre . de imediato , o mesmo solicitou a devolucao para efetuar a troca , tive despesas de correios . segundo evento apos aguardar <NUM> dias recebi o mesmo produto !!!': 1,
#   'produto veio com defeito e quebrado, pois nao recomendo pra ninguem': 1,
#   'o aparelho celular e muito bom, comprei para dar de presente de natal para meu filho, ele amou, tem muita memoria e vai ser muito bom para ele que adora baixar jogos. a camera muito boa.': 1,
#   'fraco o material parece ser descartavel, totalmente descartavel.': 1,
#   'comprei e veio com defeito a pelicula.pessima qualidade .': 1,
#   'gostaria de responder ao questionamento de uma pessoa (andre), nao faz isso nao irmao, se vc ler o manual vai verificar que existe a opcao no menu da camera de virar  na posicao que desejar, se instalo de ponta cabeca e so ir no menu e configurar para a posicao correta. a camera e muito boa, agora tem de ler o manual se nao fala bobagem.': 1},
#  {'acabei de realizar o primeiro uso e o aparelho e muito bom! os ajustes de altura sao amplos, apara muito bem, nao deixou a desejar. gostei muito.': 1,
#   'amei o produto, funciona excelentemente, chegou bem antes do prazo. muito feliz com a aquisicao. dell e tudo de bom.': 1,
#   'o produto quebrou no primeiro dia de uso. ja tive que levar em uma autorizada. extremamente fragil!': 1,
#   'amei o produto! conforme esperado! tem a opcao de <NUM> ou <NUM> xicaras, nao transborda e e super rapida! cafe sai bem quentinho!!! <<NUM>': 1,
#   'gostei muito da tv muito boa a imagem o som recomendo.': 1,
#   'de facil operacao e oferece excelente diversidade de produtos.': 1,
#   'gostei muito do produto!!!!!!!!!!!! otimo custo x beneficio': 1,
#   'prezados, produto nao chegou ate o momento, que pudemos fazer?': 1,
#   'o produto e otimo, funciona perfeitamente, custo beneficio bom, so fiquei desapontada com os <NUM> dias de atraso na entrega, mas no geral eu recomendo.': 1,
#   'produto muito bom, e entrega rapida. atende as minhas necessidades.': 1,
#   'forno e muito bom. porem e bom pra quem mora so ou casal por causa do tamanho.': 1,
#   'estorei na promocao da black friday <NUM>gb da pra fica suave por uns anos, produto perfeito, zerooo, chego muito rapido, so agradece!!': 1,
#   'geladeira top ,muito linda a entrega rapida nota <NUM>.': 1,
#   'produto de excelente qualidade entrega rapida parabens lojas americanas.faleu a compra.': 1,
#   'televisao de boa resolucao...gostei bastante e o preco foi excelente': 1,
#   'gostei muito do produto! gostei muito do produto! gostei muito do produto!': 1,
#   'muito bom o site das americanas ecelente para comprar qualquer produto .': 1,
#   'comprei a bateria da casa de impressoras, chegou muito bem embalada e bem antes da data prevista.': 1,
#   'estou no aguardo da resolucao deste gravissimo problema, pela americanas, o que me gerou muito estresse.': 1,
#   'amei o celular, produto de qualidade e espetacular. lojas americanas esta de parabens pelo comprometimento na entrega. recebi em <NUM> dias, bem antes do prazo estipulado. estou amando minha aquisicao :)': 1,
#   'a qualidade do material da pipoqueira e boa, ela e leve e facil de manusear e limpar. praticamente todas as pipocas estouram, mas tem que estar ciente de que e uma pipoca sem oleo, ou seja, o sabor nao e tao acentuado e o sal nao gruda nela porque nao tem gordura. entao tem sempre que adicionar alguma gordura (azeite, manteiga) pra pegar o sal, tempero, etc. e depois de um tempo, ela fica meio murcha. mas pra quem quer uma alternativa mais saudavel e aproveitamento do milho, compensa!': 1,
#   'comprei na pre-venda mas ja vai fazer uma  semana que lancarao e ainda nem saiu para entrega ainda, todas  as lojas da cidade ja chegarao e pelo msm preco!!!': 1,
#   'produto muito bom, ajuda bastante na hora da distracao do meu filho. facil de montar. indico.': 1,
#   'chegou com prazo menor do que o esperado! minha filha amou!': 1,
#   'otimo produto comprado na melhor loja. indico a todos.': 1,
#   'entrega super rapido e bem embalado, produto otimo': 1,
#   'produto excelente, superou minhas expectativas. entrega super rapida, chegou beeem antes do prazo previsto. super recomendo.': 1,
#   'pq nao  tem entrega desse produto para o meu cep?  qdo tiver entrega para meu endereco darei uma opiniao mais segura': 1,
#   'produto de boa qualidade.recomendo, meu filho adorou!': 1,
#   'macaco bem robusto. valeu a compra. ele e um pouco pesado, mas vai ficar no carro mesmo. aprovado pela tuv. pena nao vir com manual em portugues.': 1,
#   'voce nao esta comprando um sofa. esta comprando um problema. o prazo de entrega e grande, mas nao e cumprido. e as lojas americanas nao estao preocupadas com isto.': 1,
#   'muito bom o celular!!!! entrega e produto vieram tudo certinho!!!': 1,
#   'estou insatisfeita, a propaganda enganosa da lojas americanas. o produto nao corresponde ao produto que comprei.': 1,
#   'supriu as expectativas! otimo para viagens!! e mais facil de lavar que um liquidificador de tamanho normal!!': 1,
#   'esta faltando o dvd . liguei para besway mandaram olhar o video no youtube. mas a gente nao consegue ver passo a passo. ninguem conhece o produto. nao tem assistencia tecnica local ,  entao voce fica em haver navios com elefante branco nas maos! estou montando nao sei se esta correto ou nao. e o verao esta passando!': 1,
#   'se ele aguentase carga era otimo mais infelis mente nao guenta': 1,
#   'maravilhosa eu recomendo  esse produto .obrigada  loja americana': 1,
#   'o produto chegou corretamente e no prazo certo, gosteimuito': 1,
#   'apena a entrega foi frustativa por demorar ademais pra chegar': 1,
#   'o celular ja veio com defeito de fabrica alem de ser muito lento e devolvi o aparelho e solicitei o estorno do valor pago e me deram um vale compras e ja mandei  e-mail e nao tive resposta.': 1,
#   'o preco compensa pois nao e um produto muito caro mais esta mais barato agora me sinto decepcionada por isso.': 1,
#   'comprei <NUM> unidades e o produto nao e original, falta de respeito com o consumidor': 1,
#   'produto muito bom, por um preco bem razoavel. entrega dentro do prazo.': 1,
#   'adorei o produto, muito pratico e serviu ao proprosito prometido': 1,
#   'muito bom mesmo xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx': 1,
#   'muito bom e a entrega muito rapida, pena que o site das americanas exagera no valor do frete': 1,
#   'colocam <NUM>% algodao e quando vc vai a composicao e <NUM>% poliester.': 1,
#   'nao tem bluetooth e e muito dificil configurar a smart tv. tive muitos problemas.': 1,
#   'o acabamento da cortina deixa a desejar, ha fios soltos.': 1,
#   'produto chegou antes do previsto. fica bonito, porem apos alguns dias comecou a empenar. o painel esta "curvo", deixando um espaco entre ele e a parede. com isso, as gavetas nao permanecem fechadas. ja tive que contratar um profissional para a montagem, agora terei que contata-lo novamente para tentar o conserto.': 1,
#   'superou minhas expectativas, ia comprar o ninja iq, mas esse e muito melhor': 1,
#   'boa noite! entao se eu tivesse recebido o produto teria como avaliar, porem ate o momento nao recebi o produto, estou esperando , esta em transporta ha semanas , porem nao foi entregue ate o momento.  estou esperando ainda a entrega do produto , nuna na minha vida uma entrega de uma produto comprado com americanas , mesmo entregue por terceiros , foi tao demorada e tradata com tanto descaso , pois nao ha atualizacao no sistema , ninguem fala o que aconteceu pq o produto nao foi entregue.nem se fosse produto importado demoraria tanto, imagina produto domesmo estado .  aguardo providencias e contato !  zenilde santos': 1,
#   'o produto atende muito bem ao fim que lhe e destinado.': 1,
#   'otimo produto. chegou bem antes do prazo. muito confortavel.': 1,
#   'amei o produto, mas a transportadora nao, chegou bem amassado, como nao estava em casa a pessoa que recebeu nao conferiu.': 1,
#   'realmente a vodka absolut tem um sabor diferenciado!!!': 1,
#   'esta atendendo minhas expectativas por enquanto. a entrega foi muito eficiente, chegando antes do prazo.': 1,
#   'recebi o produto muito bem embalado e como sempre antes do prazo previsto, o visual e muito irado meu filho ficou pirado quando viu e ficou me perturbando o tempo todo para ficar com ele para jogar seu jogos... e acabei cedendo... os jogos rodam de boa...recomendo...': 1,
#   'super recomendo!!!! chegou no prazo! produto correto! sem avarias! da forma que quis!': 1,
#   'vendedor correto. comprei duas unidades. inicialmente so enviaram uma unidade mas depois enviaram a faltante. sao corretos.': 1,
#   'quando vi o preco achei ate que seria black friday,e vim correndo conferir,depois vi que nao era promocao e sim preco!': 1,
#   'otimo produto, funciona conforme especificacoes, so e necessario um pouco de leitura do manual para saber configura-lo.': 1,
#   'muito bom, apenas nao tem regulagem, ela funciona de acordo com os movimento dos pes. mas me atendeu perfeitamente.': 1,
#   'produto recomendavel. dvd com excelente capa e material extra de menu muito informativo a cerca dos bastidores da producao do filme.': 1,
#   'muito bom o aparelho, rapido, tira otimas selfie tem otimo desempenho.': 1,
#   'veio produtor errado e nao quiseram fazer a troca, tendo que levar em correios pra devolver toda burocracia': 1,
#   'ainda nao usei o produto. como texto esta curto comprei um telefone sem fio nessa loja que demorou para chegar mais de <NUM> dias do prazo , apesar dos contatos nunca tive nenhuma resposta, nao sei porque ,sera uma politica da empresa, sera que isso e a quinta vez, eleita a queridinha da internet????': 1,
#   'recebi bem antes do tempo previsto, produto veio embalado, impecavel, gostei bastante.': 1,
#   'gostei e recomendo o produto. pratico para viajar, leve e nao ocupa espaco.': 1,
#   'o livro e maravilhoso, tanto no conteudo como no objeto em si. conteudo: clarice e uma escritora muito talentosa, recomendo a todos os curiosos que conhecam sua obra. para aqueles que gostaram do primeiro contato com ela e se fascinaram com o estranhamento causado, leiam o conto "o ovo e a galinha", um dos melhores que ja encontrei. fisico: esta edicao da editora rocco esta fantastica! paginas amareladas, capa dura e com uma jacket para protecao! a jacket veio levemente amassada nas bordas superiores durante o transporte, mas nada que prejudique o livro em si. poderiam tomar um pouco mais de cuidado. <NUM> estrelas para a entrega. no geral, a compra foi otima! :)': 1,
#   'o produto e bom,mas deu muito problema na entrega. levou quase dois meses para chegar, quando chegou nos correios ainda sumiu.': 1,
#   'tive muitos problemas com p produto infelizmente. a madeira quando coloca os parafusos a madeira quebra, o plastico do puxador que devia ser de ferro qd colocou o parafuso quebrou o puxador. meu guarda roupa esta sem puxador. assim que terminou de montar meia hora depois o guarda roupa deu um vao nas portas . ele e bonito mas e muito fragil as pecas.': 1,
#   'e um produto similar...porem funciona bem; como o original.': 1,
#   'rapido, pratico e leve. dificil encontrar case que proteja totalmente a tela.': 1,
#   'nao recebi a encomenda!!! o que aconteceu??? como faco pra receber o dinheiro de volta ou o produto???': 1,
#   'bom to gostando muito recomendo quer quer praticidade esse e o produto so colocar na entrada usb ja esta funcionando': 1,
#   'produto excelente, recomendo entrega no tempo prometido.': 1,
#   'veio conforme a descricao. antes da data de entrega. super recomendo.': 1,
#   'comprei para minha esposa de presente, ja voltei a comprar produto excelente,recomendo a todos!!!': 1,
#   'o produto e bom, mas infelizmente a entrega demora. ate o momento ainda nao recebi o aparelho e ja vai fazer quase um mes!': 1,
#   'tudo bem que o preco e super salgado, mas ninguem esta sendo obrigado a compra-lo! a questao e o aparelho em si. fluidez, design, face id, cores mais vibrantes, camera ainda mais inteligente... tantas coisas num aparelho so, que fica dificil falar item por item, entao melhor so citar.': 1,
#   'estou apaixonada por este aparelho. ele e  quase perfeito. se nao  fosse pela camera frontal que nao tem estabilidade, o celular seria o melhor de todos. mas fora isso, super rapido, bateria que dura dois tranquilamente e um design lindo. isso sem falar na entrega da americanas.com que nunca falha.': 1,
#   'sugestao, melhorar a qualidade do fecho e do suporte que prende a alcas': 1,
#   'gostei do produto. veste bem e e confortavel   a numeracao corresponde a padrao veste bem com roupas decotadas  indico para quem se interessar': 1,
#   'o volume maximo e muito baixo, comprei para usar em uma sala de aula para criancas pequenas e elas nao conseguem escutar.': 1,
#   'nao e espelhado coisa nenhuma nao gostei na descricao nao fala que o espelhado e fosco ...': 1,
#   'comprei esse item para uso culinario e ate o momento so tenho algo a dizer, <NUM>/<NUM>': 1,
#   'comprei  o meu em junho de <NUM>. ate o momento nao tive nada que o desabonasse. para as minhas necessidades ele e perfeito.  pra quem  nao  utiliza muita coisa super recomendo!': 1,
#   'produto otimo, atende a tudo a que se propoe. pratico, facil de limpar.': 1,
#   'veio em perfeitas condicoes, so que veio na caixa do controle comum do xbox <NUM>, de resto tudo perfeito!': 1,
#   'produto otimo lindo vem as <NUM> toalhas do jeito da descricao otima': 1,
#   'na minha opiniao o tamanho da fonte utilizada nos textos e muito pequena. parece ser arial <NUM> e o ideal seria arial <NUM>.': 1,
#   'usei somente uma vez. parece bom. somente gostaria de saber porque  o frasco e diferente da mostrada no site. obrigada': 1,
#   'nao recebi meus produtos por favor confira com a transportadora porque eles entregaram errado eu paguei preciso receber meus produtos ligo pra vcs e nao consigo fala a ligacao cai aguardo uma posicao de vcs.': 1,
#   'recebi o produto errado. estou tentando a troca ou devolucao e nao consigo ser atendido pela americanas.': 1},
#  {},
#  {},
#  {'otimo.  produto super recomendo meu filho adorou se diverte muito chegou antes do prazo facil de montar': 1},
#  {'estes panos de prato sao otimos. muito bonitos e super absorventes, secam bem e ainda decoram a cozinha!': 1,
#   'esse produto e excelente para o dia dia, muito pratico': 1,
#   'o produto chegou dentro do prazo previsto, esta instalado, operando. o maior problema e acertar a configuracao geral do telefone, como tem ocorrido em geral, o manual e resumido, faltam melhores esclarecimentos relativos as configuracoes do telefone. mas tanto a base principal, como  o ramal, estao funcionando sem problemas.': 1,
#   'como recebi material com defeito, estou extremamente descontente com o produto. nao sei se recebi geladeira de mostruario ou reembalado, mas qualidade deixou a desejar. no aguardo para devolucao e troca por outra geladeira mais robusta.': 1,
#   'na propaganda e mil maravilha,tritura ate pedra mais na pratica e um lixo,pois comprei um para a minha esposa, assim que fez um ano estragou fui obrigado  a jogar no lixo pois nao vale apena mandar consertar.': 1,
#   'forno excelente, custo beneficio otimo, muito pratico de usar.': 1,
#   'e muito bonito o acabamento e excelente, mas a mao do pilao solta lascas quando estou usando.': 1,
#   'produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar. produto de qualidade. vale a pena comprar.': 1,
#   'o produto veio incompleto faltou seis pares de meias, ja enviei tres mensagens e ate agora nao obtive nenhuma resposta.': 1,
#   'muito bom,recomendo a entrega e segura podem confiar': 1,
#   'produto muito bom recomendo. pedido recebido muito antes do tempo indicado pela loja': 1,
#   'nao deixa a roupa lisinha e  nao e pratico, o processo de passar com este produto demora bem mais que o ferro tradicional.': 1,
#   'tenho esse produto a <NUM> ano, continua funcionando muito bem!!!': 1,
#   'estou complemente insatisfeito com a loja americanas nao recebi meu produto!!!!!!!!!!': 1,
#   'aparelho bom pra acessar redes sociais para navegar na internet. um pouco lendo pra jogos.  me atendeu bem, dentro das minhas expectativas': 1,
#   'comprei para o meu neto que ficou satisfeito com o presente': 1,
#   'prazo para entrega conforme combinado, funcionou bem, produto muito bom': 1,
#   'super recomendo , meu cabelo e bem grande, e morro de preguica fazer escova no cabelo. agora essa escova ae, adiantou muuito,  em <NUM> minutos, meu cabelo ta bafo, e nao precisa usar a chapinha depois :).': 1,
#   'estou com um grande problema com a entrega deste produto. pedi no mes de dezembro e ainda nao recebi, o produto veio todo derramado na embalagem e eu nem retirei nos correios( recusei), e ate o momento nao recebi um novo produto nem a  devolucao do dinheiro..estou muito decepcionada , nao recomendo': 1,
#   'de boa qualidade e facil de instalar.   material forte, resistente e vem acompanhado de todos os acessorios necessarios.': 1,
#   'adorei o tapete!lindo e perfeito!!!!!                       podem comprar!sem medo': 1,
#   'o aparelho e bem completo, com otima resolucao e tamanho.': 1,
#   'produto de otima qualidade, vale muito o custo-beneficio.': 1,
#   'efetuei a compra descontou do meu cartao na hora e nao foi aprovado ainda!': 1},
#  {'comprei o produto e chegou quebrado, agora quem quebrou? correio ou veio assim?  nao sei, mais a loja do marquinho ja providenciou um codigo para retornar a mercadoria.  porem agora como eufico? uso a moto pra trabalho e alem da demora de entrega veio quebrado? fica complicado elogiar uma venda assim..': 1,
#   'peco desculpas por avaliar a bicicleta ergometrica ao inves de avaliar o aparelho . o  aparelho corresponde ao que apresenta. muito funcional e ajuda bastante .  e chegou bem rapido . nota <NUM>.para o aparelho e  nota <NUM> para a entrega.': 1,
#   'otimo,aparelho lindo! superou minhas expectativas. entrega super rapida, bem antes do prazo. lojas americanas como sempre de parabens!!!': 1,
#   'produto excelente! aspira muito bem, e a limpeza do mesmo e facil de ser realizada.': 1,
#   'prazo de entrega nao cumprido e crime contra o consumidor.   art. <NUM>. o fornecedor do produto ou servico e solidariamente responsavel pelos  atos de seus prepostos ou representantes autonomos.  art. <NUM> cdc se o fornecedor de produtos ou servicos recusar cumprimento a oferta, apresentacao ou publicidade,': 1,
#   'produto extremamente caro, mas cumpre o que promete, nao tem audio e o cartao para armazenamento (micro sd <NUM>gb) na propria camera e outra fortuna, podendo chegar a <NUM>% do preco da camera.': 1,
#   'um aparelho excelente, sua camara e boa e  possue espaco para todos os aplicarivos que eu necessitava': 1,
#   'adorei a pipoqueira ela e otima estoura todo o milho.': 1,
#   'facil manuseio, facilita muito o trabalho de varrer, eliminando o uso da pa.': 1,
#   'excelente produto, deixa o cabelo super macio e hidratado': 1,
#   'o trouxe pra casa ha uns dias, dei casa, comida, armadura polida e um dia... um unico dia, pedi para que ele fosse comprar o pao e ele se negou. eu disse que era pra ele ir logo. ele gritou "vc nao e a minha mae" e bateu a porta do quarto na minha cara. nao sei mais o que fazer!': 1,
#   'otimo produto, veio bem embalado, chegou rapido. otima qualidade. veio em perfeito estado, sem arranhoes. nao tenho o que reclamar': 1,
#   'o dvd chegou em perfeito estado e rapidamente! fiquei muito satisfeito e farei mais compras.': 1,
#   'nao funciona <NUM>%, imagem sai do cel e dificil entrar novamente. qdo funciona a imagem ate e boa...': 1,
#   'simplesmente perfeito, estou apaixonada!!!! entrega super eficiente e chegou bem antes do prazo!!! vale muito a pena mesmo!!! camera um espetaculo!!!': 1,
#   'adorei e recomendo.....sem falar que a entrega e bem rapida antes do prazo.': 1,
#   'nao recebi o produto e mandei cancelar a venda. ja faz quase <NUM> dias que fiz a compra.': 1,
#   'funcional e facil de configurar. a bateria e otima e os sensores funcionam perfeitamente. eu mesmo instalei, sendo que nunca havia tido contato com central de alarmes. o unico detalhe e que os setores devem ser fechados manualmente na central. utilizando pequenos pedacos de fios para cada setor, o fechamento dos setores nao consta no manual.  e um pequeno detalhe que nao interfere na otima qualidade do produto!': 1,
#   'bom demais, bonito, leve, recomendo. bom demais, bonito, leve, recomendo.': 1,
#   'agora ficou muito mais facil extrair cravos!!! alem disso, nao fica marcado o local onde o cravo foi retirado.': 1,
#   'comprei paguei e chegou ontem so q nao veio o q eu comprei e quero q troque por mercadoria q eu comprei meu zap <NUM> resolva meu problema ou entrarei contra vcs nos orgaos responsaveis do condumidor': 1,
#   'e pequena, mas e eficiente para levar coisas para um lanche rapido.': 1,
#   'nao foram entregues os <NUM> pares de meias que faziam parte do kit. agora alem de perder tempo em fazer avaliacoes, teria que perder tempo para entrar em contato com o cac para fazer a reclamacao.  so lembrando que a opcao de comprar "sem ver" pela internet em um loja virtual e justamente nao perder tempo!!!': 1,
#   'produto bem embalado e de excelente qualidade entrega no padrao americanas, sempre antes do prazo, aprovado!': 1,
#   'sofa horrivel espuma afunda com pouco tempo de uso, ja chega com aspecto de sofa que precisa de reforma.economia na base da porcaria .': 1,
#   'tinha garrafa de rolha por muitos anos. decidi comprar com pressao pois achava que iria segurar o cafe quente por mais tempo pois com rolha abre e fecha  e na pressao nao precisa abrir a tampa, logo esperava que ficasse mais tempo. minha surpresa, pouco depois, uma hora,  o cafe ja esta morno. a outra antiga era bem melhor.  decepcao.': 1,
#   'parabens americanas! amei essa compra. entrega mais rapida que ja vi. recomendo a todos, produto muito bom, entrega super rapida.': 1,
#   'produto de otima qualidade, cujo custo/beneficio vale a pena.': 1,
#   'o som e muito baixo. nao recomendo     jkhjkhjkhgkjhjkhjlkhlkjhljkhlkjklc': 1,
#   'os farois chegaram bem embalados, funcionaram no teste e estao conforme o previsto na compra. mas porem considero que a vedacao poderia ser mais bem acabada, pois tem algumas ondulacoes nos fechamentos. vou ter que passar silicone para evitar infiltracoes.': 1,
#   'adorei meu produto, a cadeirinha e muito pratica na limpeza e acomodacao do bebe nela. muito facil de colocar e tirar. super recomendo!': 1,
#   'tudo muito bom, tudo certo. a americanas me obriga a digitar uma quantidade minima de texto pra um produto comum que eu ja afirmei que veio tudo certo e sem problemas.': 1,
#   'muito bom. se adaptou muito bem a crianca. alem de ser linda.': 1,
#   'eles colocam o produto por r$ <NUM>,<NUM> e querem tirar no frete de r$ <NUM>,<NUM>..um frete q normalmente pago <NUM> a <NUM> reais': 1,
#   'cadeira boa, resistente, de facil instalacao. meu bebe adorou virar pra frente.': 1,
#   'entrega super rapida. ja os produtos eu esperava mais, a cacarola alca nao senti confiaca!! as formas achei bem interessante!!! ja o faqueiro pessimo, nao tem acabamento, e aspero, se nao tomar cuidado pode se machucar ao usa-lo e ao lavar tbm... as bordas sao asperas, aspecto cortante!!!': 1,
#   'o produto chegou bem antes do prazo, veio muito bem embalado, parabens americanas!': 1,
#   'maravilhoso  o conjunto  de panelas  e a entrega  <NUM>.': 1,
#   'eles mandam outra fiz <NUM> p revender ja vai p <NUM> meses devolvi todas e n entregam meu dinheiro horror': 1,
#   'recomendo a compra desta sanduicheira cumpre o prometido.': 1,
#   'um bom produto...pelo valor vale a pena..recomendo pra quem quer algo simples e barato': 1,
#   'o filtro tem muita funcionalidade, e bonito e de facil instalacao.': 1,
#   'a eficiencia no servico e a qualidade do produto esta otimo.': 1,
#   'anuncio de embalagem economica contendo <NUM> tabletes porem efetuaram a entrega de apenas <NUM> comprimido e ninguem resolve o problema, nem lojas americanas e nem a empresa fornecedora foxpet. nao comprem!!! uma enganacao!!!': 1,
#   'produto de qualidade e preco baixo! recomendo!  entregou entes da data!': 1,
#   'muito boa, facil de configurar, chegou com <NUM> dias, so isso ja valeu a pena. recomendo.': 1},
#  {},
#  {'o organizador e muito bom para quem nao tem espaco em gavetas. deixa os sutias preservados. poderia ter um fecho nas bolsas para nao ficar pendente com o peso do sutia. eu recomendo.': 1,
#   'amei o produto bom demais sem defeito recomendo outras pessoas comprarem tambem com certeza coisa otima faz uma prancha rapidinho ajuda demais': 1},
#  {'excelente pois ajudou a aproximar ainda mais eu (pai) da minha filha': 1,
#   'produto bom. so acho q nao deveria absorver manchas': 1,
#   'ate o presente momento ainda nao recebi as pernas da mesma indignacao !!! ja se passaram mais de um mes da entrega porem nada': 1,
#   'suga bem as bolinhas que vem junto. bem legal, mas achei bem pequeno.': 1,
#   'adquiri a estante em <NUM> , esta em perfeitas condicoes ate hoje .': 1,
#   'eu uso essa racao tanto para cao como para o gato , ha <NUM> meses ja, estou gostando bastante e eles tambem.': 1,
#   'preciso adquerir <NUM> unidades deste carrinho de mao como deve procedr e qual e politica da firma. temos cnpj e insc estadual antonio s santos <NUM>. <NUM>.<NUM>': 1,
#   'eu gostei do produto,e realmente o que esperava,satisfeita.': 1,
#   'excelente pendrive nao tem muito o que falar. cumpre o que promete.': 1,
#   'ele carrega, mas nao como turbo. devolvi o produto.': 1,
#   'produto entregue nao corresponde ao da imagem ... precisavamos de um com <NUM> pinos para as <NUM> entradas e saida e enviaram com <NUM> pinos p/ entradas e saida (sem o terra).': 1,
#   'ate o presente momento o produto ainda nao foi entregue, portanto nao tem como avaliar o prazo de entrega esta estipulado no maximo para <NUM>/<NUM>/<NUM>, estou no aguardo.': 1,
#   'atendeu as expectativas. podem comprar sem medo e o vendedor tambem e confiavel.': 1,
#   'comprei chegou super rapido gostei bastante do tapete': 1,
#   'um mes de prazo para entregar dia <NUM> de abril, e agora simplesmente dizem que vai ser la para maio. pessimo.!': 1,
#   'produto de qualidade,entrega rapida e atendimento rapido e de qualidade, eu indico comprar com a casa game': 1,
#   'muito bom. excelente.................................................................................................................................................... ............   . . . . . . . . . .  .. . .  . . . . . . . . . . .': 1,
#   'estou usando o notebook a pouco tempo mas tudo indica que e bom. o acabamento e de qualidade e a entrega muito tranquila. tenho outros note dessa mesma marca e estou satisfeito': 1,
#   'distribui bem o calor e o conserva por igual. vai do fogo ao forno com muita competencia no preparo de carnes.': 1,
#   'tv lixo, nao da pra instalar nenhum app.... joguei <NUM> reais no lixo.... porcaria......': 1,
#   'produto chegou bem antes do prazo informado. otima qualidade.': 1,
#   'celular muito limitado, camera com defeito, atraso na entrega': 1,
#   'gostei e uma mistura do mortal kombat com o injustice da dc comics': 1,
#   'gostei muito.  entregou antes da data prevista. o produto e de qualidade. super indico.': 1,
#   'a carga dele dura quanto tempo??????????????????????????????????????????????': 1},
#  {'a embalagem nao e a mesma da oferecida em foto. acredito que a quantidade seja muito menor tambem. poderia ter comprado mais cola pois essa que ofereceram acredito que nao de para efetuar o trabalho., e sendo assim terei que pagar novo frete para comprar mais cola.': 1,
#   'pessimo. nao me refiro ao conteudo do livro, pois isso e subjetivo, mas o livro veio com paginas faltando - pulava da fl. <NUM> direto para a fl. <NUM>. alem disso, muitas paginas coladas.': 1,
#   'manual nao explica corretamente material pessimo  fabricante deveria esplicar melhor marcar corretamente como montar.': 1,
#   'adoro comprar com a americanas! sempre entregando adiantado e qualidade garantida!': 1,
#   'gostei muito, boneco bem detalhado. e veio com pilhas inclusas.': 1,
#   'veio com o espelho quebrado e a porta da direta venho branca sendo que da esquerda e rosa . e eu comprei pra minha filha na cor rosa. decepcionado ,pois tentei inura vezes tentar entra em contato pra troca das pecas e nada ate agora.': 1,
#   'amei o produto....comprem se voce e daqueles que le os comentarios eu tbm faco isso por isso comprei :) eu ia pagar para montarem porem meu marido seguiu o passo a passo pelo youtube e pela primeira vez nao sobrou parafuso...rsrs produto de otima qualidade se tivesse como mandar a foto eu mandaria para ver como ficou no quarto do meu filho. https://www.youtube.com/watch?v=zu<NUM>r<NUM>sjm<NUM>y esse e o link da montagem': 1,
#   'sou suspeito a falar pq sou fa da marca sony.. porem as cameras e o aparelho e muito bom': 1,
#   'gostei do produto muito bom comprei <NUM> ja estou usando a metade recomendo entrega super rapida muito obrigado': 1,
#   'otimo produto, imegem exelente, transportadora fraca demais': 1,
#   'comprei entrega a jato para entregar em <NUM> dia util , comprei na quarta <NUM> da manha hj ja e  quinta <NUM>hrs da noite e nao recebi meu produto infelizmente nao cumpriram com oque prometeram': 1,
#   'produto muito bom pra quem quer praticidade, fora que minha coluna  agradece.': 1,
#   'material leve e resistente. super util e facil d remontar e desmontar.': 1,
#   'nao esta especificado no anuncio ser original ou nao... falta claresa... comprei um produto achando que era outro... qualidade de audio e materiais muito ruins.': 1},
#  {},
#  {},
#  {'adorei esse celular, tudo que eu preciso tem nele!! superou todas as minhas expectativas.': 1,
#   'pessimo atendimento da americanas . com  , ou melhor nen atendido eu fui': 1,
#   'produto excelente!! amei o efeito em meus cabelos, que estavam quebradicos elasticos, e na primeira aplicacao ja deu uma grande diferenca. entrega feita antes do prazo.': 1,
#   'qualidade do produto e tao <NUM> que dispensa comentarios. entrega entao, nem se fala, no site fui informado de que receberia a mercadoria e ate <NUM> dias, mas para minha surpresa recebi no segundo dia util. tao bom que se melhorar estraga.': 1},
#  {'demora na entrega, veio com um oringue rasgado e a parte de cima e de um material de baixissima qualidade longe de ser de ferro!': 1,
#   'cartucho <NUM> xl caro com maximo de <NUM> impressoes.': 1,
#   'jogo otimo...mto original com estadios brasileiros perfeitos': 1,
#   'produto bom, entretanto, a entrega atrasou muito, prejudicando o custo/ be': 1},
#  {'comprei para uso domestico e funcoes basicas, portanto estou satisfeita. o produto e muito bonito e moderno.': 1,
#   'comprei um jogo de caneca e o vendedor me enviou outro, mandei email e ele nem me respondeu.': 1,
#   'o dragao sopra um vapor e a luz vermelha em sua boca produz um efeito lindo! uma graca!': 1,
#   'o produto e muito bom e atendeu completamente as minhas expectativas': 1,
#   'o produto e muito lindo!!! gostei, porem soltou tinta dessa parte rosa e deu uma manchada nele e em outros biquinis que estavam junto, e so tinha lavado com shampoo e sabonete, estava em um hotel e nao tinha como pendurar separado pra secar logo.': 1,
#   'amei esse aparelho de jantar!! e lindo, material resistente e e branquinho sim!! achei ainda mais bonito que nas fotos! pelo valor que paguei (r$<NUM>,<NUM>) compensa muito!': 1,
#   'fiz uma simulacao de frete. o frete para meu endereco ficou em torno de <NUM>,<NUM>. absurdo.': 1,
#   'minha esposa gostou muito  ,esta satisfeita;; produto muito bom recomendo ...': 1,
#   'produto de boa qualidade e entrega no prazo combinado.': 1,
#   'muito bom. recomendo, e otimo. foi recomendado pela minha sobrinha. meu cabelo esta bem melhor, cresceu, forte e diminuiu a queda.': 1,
#   'linda casinha, encantada por ela, minha filha mais ainda... ❤❤❤❤❤❤': 1,
#   'nunca tive problemas em compras com vcs,mas ate agora <NUM>/<NUM>/<NUM>,as <NUM>,<NUM> hs nao recebi o cabo comprado com vcs,mas como o prazo inicial era ate o dia <NUM>/<NUM> vou aguardar mais um pouco.espero que de tudo certo': 1,
#   'a entrega foi super rapida, muito antes do prazo. o produto veio em perfeitas condicoes, tem imagem e audio otimos, e super leve. a regiao que eu moro nao tem um sinal muito bom, entao precisamos de uma antena digital para conseguir sintonizar os canais.': 1,
#   'sempre leve, nao tem como mudar para ficar pesado, e a porcaria do apareco que mostra a velocidade nao funciona  liga tudo mas so tem uma opcao. nao comprem nada dessa marca.': 1,
#   'ja comprei alguns produtos da mesma marca e linha e tiveram uma durabilidade aceitavel quando considerando o uso, bom custo beneficio.': 1},
#  {'chegou no prazo. diversas funcionalidades. produto excelente. eu recomendo.': 1,
#   'relogio lindo, adorei! entrega antes do prazo pela sintonia digital, super recomendo!!!': 1,
#   'muito bom recomendo este produto ate agora nao apareceu nenhum defeito': 1,
#   'excelente produto, processador muito rapido, mais rapido que a lg <NUM>k que comprei antes dela': 1,
#   'a mangueira chegou na data certa mas veio furada nuca tive problema em compra com vcs mas nao sei como trocar mangueira estou esperando um parecer de voces.': 1,
#   'otimo custo beneficio, vale o preco pelo otimo hardware...': 1,
# ...
#   'atendeu minhas expectativas dentro do valor e ao que se propoe o produto anunciado.  possui design moderno com uma  iluminacao perfeita. agua na temperatura desejada. por enquanto so elogios.': 1,
#   'celular muito bom e bonito, excelente produto, estou muito satisfeito com essa compra.': 1,
#   'produto chegou muito rapido, produto atende ao q preciso , amei': 1,
#   'otimo produto, com custo bom. valeu a pena comprar.': 1,
#   'ainda que pareca obvio, por que um player de venda consolidado como a americanas esta a comercializar um equipamento de acesso pirata aos canais de tv paga?  ou estou equivocado e sim, e um equipamento amparado pela lei brasileira?': 1,
#   'realmente e um  lindo pingente de pedra natural banhado a ouro. linda! amei!': 1,
#   'qdo receber a cafeteira darei minha opiniao . pois nao cheguei a usar a mesma.': 1,
#   'nao tem como nao se apaixonar por gideon e eva e sua historia cheia de amor, desejo e final surpreendente de um amor importavel de duas pessoas complicadas e traumatizadas.': 1,
#   'eu ja uso este produto a muito tempo . recomendo.otimo pa  rachadura no pes': 1,
#   'produto de boa qualidade, montagem facil. entrega efetuada antes do previsto. recomendo!!!': 1,
#   'tenho o meu a mais de um ano e ate hoje o sofa esta perfeito, podem comprar sem medo.  muito bonito e super confortavel.': 1,
#   'das <NUM> pecas anunciadas, <NUM> estao com defeito! nao consigo contato com a americanas, nem com a loja para a solicitacao da troca das pecas com defeito!!!': 1,
#   'pensei que fosse maior,achei muito pequeno te como trocar': 1,
#   'tem movimentos oculares , material resistente . lavavel': 1,
#   'pontos fortes: - resolucao alta - bom contraste - bordas finas - vira na vertical - construcao robusta  pontos fracos: - demora: a dell so vende hardware, e mesmo assim demorou quase <NUM> dias para me entregar o monitor. nao compre se estiver com pressa. - windows. mesmo estando com a versao mais recente do windows <NUM>, e notorio como ate hoje o sistema nao funciona bem em alta resolucao. diversos programas ficam borrados ou mesmo desconfigurados. mas isso nao e culpa do monitor. - drivers. quando liguei o monitor pela primeira vez, achei a calibragem padrao um pouco amarelada. entrei no site da dell e resolvi baixar o driver oficial do monitor. o windows simplesmente bloqueou dizendo ser virus. e nao ha outro lugar para se conseguir o driver.  veredito: - excelente compra, estou super satisfeito. apesar da demora, considero que valeu a pena a espera. e o atendimento da dell tambem foi de grande qualidade. <NUM> estrelas.': 1,
#   'produto cumpre o que promete. satisfeita com a compra!': 1,
#   'ja rasgou na costura de tras, e muito pequena, mal cabe na cabeca, o cheiro do produto e tao forte que so se pode usar enquanto conseguir prender a respiracao': 1,
#   'pote sao de vidro resistente e tampas fechas muito bem,vedamento otimo.': 1,
#   'produto chegou dentro do prazo obrigado pela atencao!': 1,
#   'gostei do produto,  o tamanho e excelente e o material do corpo da panela tambem, o que me deixou a desejar foi em relacao ao cabo, achei fragil em relacao ao peso da panela, nao parece muito confiavel.': 1,
#   'boa tarde ! deve ter algum engano ,porque meu produto ainda nao chegou , nao da para avaliar': 1,
#   'otimo produto, entrega rapida, recebi antes do previsto. indico a todos o celular e o site.': 1,
#   'muito bom, de facil utilizacao. muito bom mesmo. estou adorando.': 1,
#   'facil de usar so a o cabo entrada semelhante ao s<NUM> dificil de achar se o cabo der problema ...': 1,
#   'otimo  produtos!! tem um bom  desainer! atende minhas expectativa!!': 1,
#   'tl;dr; custo beneficio excelente.  --- tenho ele faz <NUM> ano, recomendo formente. notebook leve, silencioso, nao esquenta igual a torradeira do hp-g<NUM> q eu tinha.   utilizo para programacao, entao o i<NUM> + <NUM> gb de ram atende perfeitamente para rodar android studio, e outras ides mais parrudas.  alem do trabalho utilizo para lazer, roda a maioria dos jogos no medium, em um fps bem agradavel para jogar.   um notebook com placa de video (mesmo q singela) faz toda a diferenca.': 1,
#   'muito boa superou minhas expectativa, porque os modelos anteriores nao limpava tao bem agora essa e excelente, nao ha necessidade de usar o tanquinho antes ela limpa mesmo!!!!': 1,
#   'meu produto nao foi entregue ate a presente data. produto nao chegou ao destino. aguardo retorno para possivel posicionamento.... grata ate o momento ........': 1,
#   'pode ser bom em outros quesitos, mas um de extrema importancia e basico nao possui: nao acessa o meu hd externo seagate <NUM> tb. fiz contato com a lenovo que diz nao ser ser um problema dela, mas fica claro que se trata de um problema na maquina pois pesquisando nos foruns da lenovo vemos que varios usuarios passam pelo mesmo problema com ideapad<NUM> com diversas marcas de hd externo. alem disso o hd funciona em todos os outros computadores, inclusive em um lenovo mais antigo, e tambem fiz contato com o suporte da seagate que confirmou que nao existe nenhuma incompatibilidade com sistema ou maquina.   se vc precisa usar um hd externo com esse notebook, nao compre.': 1,
#   'produto atendeu as minhas expectativas em preco e funcionalidade, alem da economia com filtro de papel .': 1},
#  {'chegou com codex um pouco mucho mas esta recuperando estou feliz obrigada': 1},
#  {},
#  {'o produto veio estragado.ele nao esquenta e nem funciona. nao recomendo a ninguem que compre , nao vale a pena. solicitei a devolucao do produto.': 1,
#   'nao posso avaliar o que ainda nao recebi. foi me passada a previsao de entrega do livro para <NUM>/<NUM> e hoje ja e <NUM>/<NUM> e ate o momento minha encomenda nao chegou.': 1,
#   'muito abaixo das minhas expectativas,.........sem mais palavras': 1,
#   'o astolfo e incrivel! as fotos de todos os angulos do produto e a descricao completa me deram muita seguranca na compra. obrigada a loja!': 1,
#   'otima tv chegou rapido de mais os hdmi em um lugar facil de instalar mi empreciono muito com a imagem dela': 1,
#   'o celular e bom d+, tem uma otima camera e ainda ganhei bastao de selfi. o celular chegou muito rapido .': 1,
#   'o produto e honesto em comparacao com seu preco. esse modelo de camera passou a ser fabricado no brasil. a compra foi um presente para minha sobrinha que esta gostando muito do produto. so sentimos falta de um manual do produto. se bem que e possivel baixa-lo da internet.': 1,
#   'otimo produto, muito potente, superou minhas expectativa.': 1,
#   'o produto e muito bom mas infelizmente o meu veio com dois risco no pe da mesa.': 1,
#   'me arrependi de ter comprado o acabamento mal feito dos garfos corta a boca. nao compre': 1,
#   'excelente produto, perfeito para quem trabalha com locacao ou para quem tem filhos!': 1,
#   'chegou antes do prazo, potes lindos, resistentes e de otimo tamanho. recomendo!': 1,
#   'primeiramente, nao e um espelho. parece um cartao espelhado, a imagem fica totalmente distorcida. mesmo tendo as medidas no site, pensei que fosse maior. de qualquer forma, fui ate uma vidracaria e agora compramos um espelho para a sala.': 1,
#   'recebi no prazo , produto de boa qualidade e bem util.recomendo': 1,
#   'a tv fica reiniciando sozinha o tempo todo, principalmente nos canais digitais.': 1,
#   'o celular chegou na residencia sem a nota fiscal, ate agora nao sei quem tirou a nota fiscal pois o correio nao sabe dizer.': 1,
#   'muito bom, a camera e excelente,boa memoria interna, unico problema que e comum a varios motorola e que a bateria esquenta muito em uso de aplicativos que usam muito processamento .': 1,
#   'recomendo.. chegou antes do prazo e e facil de manusear': 1,
#   'recebi o produto com defeito! ja devolvi e nao resolvem meu problema!!!': 1,
#   'pensei que fosse pequena a mochila e muito grande nao fala a medida na descricao e na foto parece pequena': 1,
#   'muito bom, porem o manual nao consta o procedimento de acerto do relogio': 1,
#   'ja fiz bolo nela e muito bom deixa a textura da massa no ponto mais rapidamente =d.': 1,
#   'muito pratico, so faltou uma entrada rj<NUM> e um processador mais rapido (ai seria perfeito), mas atendeu bem minha necessidade. recomendo.': 1,
#   'indico bem pratico! sistema operacional bom! gostei muito da praticidade e rapidez das lojas americanas...': 1,
#   'relogio bonito e com bom acabamento. nao e grande e seria interessante se fosse um pouco maior, porem e pratico e usual.': 1,
#   'ainda e cedo para dizer sobre o produto, mas ate o momento esta atendendo.': 1,
#   'robusta e potente parece muito forte  so testei ainda nao usei': 1,
#   'estou aguardando uma resposta, agora nada...mandam aguardar <NUM>,<NUM> dias uteis .e ja fez um mes que comprei e nadaaa': 1,
#   'muito bom, recomento o produto e entrega em tempo habil.': 1,
#   'otimo custo beneficio, o produto e muito bom, exceto por um detalhe: nao e possivel  guardar ele na vertical, de resto estou satisfeita com a compra.': 1,
#   'e lindo, apaixonante!  fiquei tao encantada com a beleza que ainda nao tive coragem de usar...rs': 1,
#   'ja paguei um boleto bancario e nunca mais compro nada desta fraude. o pedido nunca vai para o site e seu dinheiro nunca mais.': 1,
#   'amei a cor. .... sao muito mais bonitos ao vivo..... comprarei mais ....': 1,
#   'gostei muito do produto e ainda recebi antes do esperado.': 1,
#   'para quem gosta do controle classico, e a melhor opcao.': 1,
#   'o produto veio e fui atendido pelo sac quando fiz prgntas. recebido e  gostei do produto.': 1,
#   'muito bom, eu mesmo montei achei que fosse dificil, mas foi moleza rss  igual da foto': 1,
#   'gostei.... so que pedi branco e veio preto. recomendo': 1,
#   'produto muito bom, boa qualidade, facil instalacao, alem de entrega rapida !': 1,
#   'excelente compra: bom preco; chegou antes do prazo e excelente qualidade do produto.': 1,
#   'funcionou ,maravilhosamente! usei para medir o nivel de assoreamento de um manancial,possibilitou verificar a formacao fisica do fundo do lago!': 1,
#   'e um plastico que imita borracha (muito de longe, por sinal). e a tampa e de plastico e nao de inox. alem de tudo, ela e de enroscar. muito decepcionado!': 1,
#   'entrega super rapida...nunca tive problemas com produtos da loja...': 1,
#   'o livro chegou muito bem protegido e antes do prazo.  a tempo de comecar o uso na escola da minha pequena.': 1,
#   'apesar de nao estar descrito o produto e de plastico tipo pet. tentei devolve-lo seguindo o protocolo do site no dia que recebi. o e-mail recebido apos o pedido informava que em <NUM> receberia uma resposta, ate hoje nenhum contato . pessima compra. nao recomendo ! nenhum apoio do revendedor ...': 1,
#   'veio faltando pecas ou seja ele veio sem fundo e as furacoes nao bate e quando motado fica desalinhado': 1,
#   'recebe corretamente produto de qualidade conforme o anuncio': 1,
#   'ainda nao recebi o produto como posso avaliar? o produto era para ser entregue dia <NUM>/<NUM> passaram o prazo para dia <NUM>/<NUM> e ate agora nao recebi.': 1,
#   'super indico! ja estou programando um jantar para minha nora, para estrear meu jogo de talheres': 1,
#   'muito facil de instalar, muito facil de navegar! apaixonei!': 1,
#   'produto excelente e original. ja quero comprar mais! super recomendo!': 1,
#   'muito show um dos melhores e um custo e beneficio incomparavel... atendimento nota <NUM>': 1,
#   'apos ler varios comentarios sobre o produto decidi comprar este modelo posso dizer que ela e otima faz pipoca em <NUM> minutos o sabor e delicioso. adorei muito e meu filho que ama pipoca tambem adorou demais faz festa ao ver a pipoca caindo no pote.': 1,
#   'gostei muito, chegou bem antes e funciona muito bem.': 1,
#   'produto e recomendavel porque esta dentro das especificacoes. so tem um senao: comprei na quantidade dois(<NUM>) e recebi apenas um (<NUM>), ate agora. <NUM>/<NUM>/<NUM>.': 1,
#   'otimo custo beneficio. tamanho ideal. silenciosa. mantem a temperatura': 1,
#   'celular pessimo, nao reconhece wi-fi, volume baixo, tenho dificuldades para ouvir tudo ( ligacoes, videos, audio) e nao reconhece nenhum aplicativo gps (ja me perdi varias vezes e os aplicativos baixados nao funcionam nesse celular). terrivel. quanto a americanas, sempre muito boa na entrega e no prazo.': 1,
#   'otimo produto. recomendadissimo. podem comprar sem medo.': 1,
#   'produto de boa qualidade! atendeu as minhas espectativas': 1,
#   'atendeu as expectativas . recomendo a todos. preco muito bom': 1,
#   'comprei dia <NUM>/<NUM>/<NUM> e estou esperendo o celular ainda.': 1,
#   'muito bom o produto, leitura facil. recomendo a leitura.': 1,
#   'otimo ventilador,muito satisfeito com produto recomendo com certeza!!!': 1,
#   'responde bem as expectativas . esquenta bem. uma boa opcao para quem quiser ver seus cabelos lisos.': 1,
#   'adorei o fogao! muito lindo e pratico. valorizou a minha cozinha. recomendo!': 1,
#   'o produto tem o acabamento pessimo. a caixa de plastico que envolve o circuito e fragil e mal fechada. a conexao com o cabo vga e frouxa causando sensibilidade no encaixe e consequentemente ruido e alternancia no brilho da imagem da segunda tela. a primeira vista e claramente um produtor com pessima robustez, nao acredito que va durar muitas horas de uso.': 1},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'otima compra, o modelo atende perfeitamente a expectativa. muito funcional,': 1,
#   'melhorar o sistema de entrega para que chegue a tempo abiu': 1,
#   'protuto de muito boa qualidade, incentiva a interacao e descoberta': 1,
#   'comprei uma mangueira de <NUM> metros e me chegou aqui em casa uma com <NUM> metros,na primeira vez que vou usar nao aguentou a pressao da agua e estourou no encaixe da pistola.sendo que era uma mangueira que supostamente esticava com a pressao. me senti enganada!': 1,
#   'recebi um e-mail da americanas para cancelar o pedido pois o produto nao tinha sido enviado.  pedido cancelado e esperando estorno.': 1,
#   'boa noite,esse produto eu recomendo sim,mas o site eu estou decepcionada pois comprei um celular on<NUM> ja faz um ano mas so agora vim descobrir que comprei gato por lebre ,o celular veio escrito na bateria made in china,entao ele e importado ,e eu confiei no site,estou decepcionada com site americanas': 1,
#   'tinha o s<NUM> e mudei para o s<NUM>, amei a tela e o processador o melhor ate agora': 1,
#   'aparelho com bateria resistente!  entrega rapida antes do prazo final': 1,
#   'empresa com atendimento ao cliente otima, muito agil para tirar as duvidas e mais, o movel chegou antes da data prevista, recomendo a todos': 1,
#   'demoraram para responder e nao tinha o produto que compre...': 1},
#  {},
#  {},
#  {},
#  {},
#  {'produto muito bom, tem o cabo maior do que outros que olhei, facilita muito a limpeza de casa. e sobre a americanas, como sempre entregou muito antes do prazo! pedi numa terca feira a noite, no sabado de manha o produto chegou.': 1,
#   'gostei bastante, o notebook se comporta muito bem, mesmo em stress, da pra jogar bastante coisa (gta v, bf<NUM>, lol...), o unico problema e que o processador fica debaixo do w a s d, entao esquenta muito, as vezes a ponto de incomodar. alguns programas que vem pre-instalados atrapalham um pouco, como o anti-virus. a tela e boa, mas nada excepcional, o som e de qualidade, mesmo em volumes mais altos ele nao perde o foco. o hd faz um barulho caracteristico, mas nada que atrapalhe, pode incomodar pra quem e mais exigente quanto a ruido. o acabamento e bonito e ele e bem leve, sem falar na possibilidade de adicionar um novo hd ou ssd, devido ao slot de gravador de cd estar vazio. no geral e um excelente computador, comprei com o intuito de usar para trabalho, mas como gosto de games, instalei alguns, os quais funcionaram muito bem, entao mesmo sendo um computador de trabalho posso leva-lo onde for que vou me divertir.': 1,
#   'recomendo a todos a compra excelente qualidade entrega no prazo': 1},
#  {'produto excelente!recomendo a todos!em muito antes do prazo.': 1,
#   'celular top!! recomendo. a camera e maravilhosa, a tela... tudo muito bom.': 1}]

# %%
doc_count = np.array(mgp.cluster_doc_count)

# %%
# Show the top 5 words in term frequency for each cluster 
top_words(mgp.cluster_word_distribution, top_index, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-a156b364ee67> in <module>
#       1 # Show the top 5 words in term frequency for each cluster
# ----> 2 top_words(mgp.cluster_word_distribution, top_index, 5)
#
# NameError: name 'top_words' is not defined

# %% [markdown]
# ### Gibbs Sampling Dirichlet Mixture Model (GSDMM)

# %% [markdown]
# ## NLP for Hackers

# %%
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /home/saraiva/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
from nltk.corpus import brown
 
data = []
 
for fileid in brown.fileids():
    document = ' '.join(brown.words(fileid))
    data.append(document)
 
NO_DOCUMENTS = len(data)
print(NO_DOCUMENTS)
print(data[:5])
# Out:
# 500
# ["The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place . The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted . The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to investigate reports of possible `` irregularities '' in the hard-fought primary which was won by Mayor-nominate Ivan Allen Jr. . `` Only a relative handful of such reports was received '' , the jury said , `` considering the widespread interest in the election , the number of voters and the size of this city '' . The jury said it did find that many of Georgia's registration and election laws `` are outmoded or inadequate and often ambiguous '' . It recommended that Fulton legislators act `` to have these laws studied and revised to the end of modernizing and improving them '' . The grand jury commented on a number of other topics , among them the Atlanta and Fulton County purchasing departments which it said `` are well operated and follow generally accepted practices which inure to the best interest of both governments '' . Merger proposed However , the jury said it believes `` these two offices should be combined to achieve greater efficiency and reduce the cost of administration '' . The City Purchasing Department , the jury said , `` is lacking in experienced clerical personnel as a result of city personnel policies '' . It urged that the city `` take steps to remedy '' this problem . Implementation of Georgia's automobile title law was also recommended by the outgoing jury . It urged that the next Legislature `` provide enabling funds and re-set the effective date so that an orderly implementation of the law may be effected '' . The grand jury took a swipe at the State Welfare Department's handling of federal funds granted for child welfare services in foster homes . `` This is one of the major items in the Fulton County general assistance program '' , the jury said , but the State Welfare Department `` has seen fit to distribute these funds through the welfare departments of all the counties in the state with the exception of Fulton County , which receives none of this money . The jurors said they realize `` a proportionate distribution of these funds might disable this program in our less populous counties '' . Nevertheless , `` we feel that in the future Fulton County should receive some portion of these available funds '' , the jurors said . `` Failure to do this will continue to place a disproportionate burden '' on Fulton taxpayers . The jury also commented on the Fulton ordinary's court which has been under fire for its practices in the appointment of appraisers , guardians and administrators and the awarding of fees and compensation . Wards protected The jury said it found the court `` has incorporated into its operating procedures the recommendations '' of two previous grand juries , the Atlanta Bar Association and an interim citizens committee . `` These actions should serve to protect in fact and in effect the court's wards from undue costs and its appointed and elected servants from unmeritorious criticisms '' , the jury said . Regarding Atlanta's new multi-million-dollar airport , the jury recommended `` that when the new management takes charge Jan. 1 the airport be operated in a manner that will eliminate political influences '' . The jury did not elaborate , but it added that `` there should be periodic surveillance of the pricing practices of the concessionaires for the purpose of keeping the prices reasonable '' . Ask jail deputies On other matters , the jury recommended that : ( 1 ) Four additional deputies be employed at the Fulton County Jail and `` a doctor , medical intern or extern be employed for night and week ...

# %%
import re
from gensim import models, corpora
from nltk import word_tokenize
from nltk.corpus import stopwords
 
NUM_TOPICS = 10
STOPWORDS = stopwords.words('english')
 
def clean_text(text):
    tokenized_text = word_tokenize(text.lower())
    cleaned_text = [t for t in tokenized_text if t not in STOPWORDS and re.match('[a-zA-Z\-][a-zA-Z\-]{2,}', t)]
    return cleaned_text
 
# For gensim we need to tokenize the data and filter out stopwords
tokenized_data = []
for text in data:
    tokenized_data.append(clean_text(text))

# %%
# Build a Dictionary - association word to numeric id

 
# Transform the collection of texts to a numerical form
# Out:
# [(12, 3), (14, 1), (21, 1), (25, 5), (30, 2), (31, 5), (33, 1), (42, 1), (43, 2), (44, 2), (45, 2), (46, 2), (47, 2), (49, 1), (50, 1), (53, 1), (56, 1), (59, 1), (60, 1), (66, 1), (75, 1), (80, 1), (98, 1), (101, 1), (106, 1), (117, 1), (129, 1), (130, 2), (132, 2), (135, 2), (140, 1), (141, 2), (143, 4), (144, 2), (145, 2), (166, 1), (195, 1), (198, 3), (219, 1), (220, 4), (221, 3), (223, 1), (229, 4), (230, 4), (231, 2), (235, 1), (236, 1), (242, 2), (246, 2), (255, 1), (263, 1), (269, 1), (270, 5), (271, 2), (275, 5), (276, 1), (278, 4), (280, 2), (281, 1), (307, 2), (310, 1), (311, 3), (313, 1), (314, 5), (318, 4), (322, 1), (336, 1), (338, 3), (339, 1), (340, 1), (341, 1), (345, 1), (346, 1), (351, 1), (354, 1), (355, 1), (366, 3), (368, 13), (370, 1), (372, 1), (374, 3), (377, 3), (381, 3), (386, 1), (392, 6), (396, 1), (401, 1), (412, 2), (426, 2), (428, 2), (431, 2), (434, 2), (439, 2), (444, 1), (450, 1), (452, 1), (462, 1), (465, 1), (467, 1), (470, 1), (478, 1), (483, 1), (484, 1), (504, 1), (513, 1), (517, 3), (520, 1), (522, 1), (523, 21), (526, 2), (530, 1), (532, 7), (542, 2), (545, 2), (553, 5), (566, 2), (578, 1), (584, 1), (588, 1), (595, 2), (597, 3), (598, 1), (600, 2), (603, 3), (607, 1), (613, 4), (633, 2), (640, 2), (645, 2), (649, 1), (651, 1), (653, 6), (654, 2), (655, 1), (675, 2), (680, 4), (686, 2), (688, 1), (710, 1), (713, 2), (721, 1), (725, 1), (726, 1), (733, 1), (734, 1), (735, 9), (747, 1), (748, 1), (762, 1), (768, 2), (776, 1), (783, 1), (784, 1), (808, 2), (815, 1), (830, 1), (842, 8), (862, 1), (865, 2), (871, 1), (879, 1), (882, 5), (883, 3), (888, 3), (890, 1), (898, 2), (899, 1), (901, 1), (903, 1), (913, 1), (923, 1), (924, 2), (929, 2), (930, 1), (931, 1), (936, 1), (940, 1), (941, 1), (942, 3), (946, 1), (963, 1), (965, 1), (972, 1), (994, 1), (995, 1), (998, 1), (999, 1), (1000, 1), (1022, 1), (1048, 1), (1060, 1), (1061, 2), (1101, 1), (1104, 1), (1106, 2), (1107, 3), (1121, 1), (1122, 1), (1128, 1), (1132, 4), (1155, 1), (1160, 1), (1182, 1), (1184, 1), (1188, 2), (1191, 8), (1200, 1), (1203, 1), (1213, 1), (1216, 1), (1217, 3), (1222, 1), (1223, 1), (1244, 1), (1253, 1), (1270, 1), (1272, 1), (1275, 1), (1303, 5), (1304, 1), (1315, 1), (1337, 1), (1339, 5), (1355, 1), (1362, 1), (1367, 1), (1378, 1), (1381, 1), (1391, 1), (1397, 1), (1419, 1), (1422, 1), (1426, 1), (1433, 1), (1453, 3), (1456, 1), (1463, 1), (1467, 1), (1470, 2), (1484, 3), (1485, 1), (1489, 1), (1497, 1), (1503, 1), (1507, 1), (1510, 1), (1514, 1), (1517, 1), (1520, 1), (1521, 1), (1522, 1), (1527, 2), (1543, 10), (1544, 3), (1547, 4), (1554, 1), (1556, 1), (1561, 1), (1568, 1), (1576, 1), (1589, 1), (1603, 1), (1608, 4), (1609, 1), (1612, 1), (1622, 2), (1637, 3), (1641, 3), (1642, 3), (1659, 2), (1660, 1), (1670, 1), (1692, 1), (1696, 1), (1699, 1), (1712, 3), (1741, 1), (1751, 1), (1756, 1), (1764, 2), (1777, 2), (1782, 1), (1783, 3), (1820, 1), (1830, 1), (1835, 2), (1837, 1), (1844, 1), (1845, 6), (1850, 1), (1862, 3), (1871, 1), (1875, 1), (1884, 3), (1888, 1), (1891, 3), (1906, 1), (1941, 1), (1946, 1), (1965, 2), (1967, 1), (1968, 2), (1984, 2), (1986, 1), (1991, 1), (1993, 2), (2011, 1), (2043, 1), (2044, 2), (2053, 1), (2060, 1), (2066, 2), (2069, 2), (2105, 1), (2107, 1), (2130, 1), (2138, 1), (2158, 1), (2161, 2), (2175, 2), (2176, 1), (2177, 1), (2182, 1), (2186, 1), (2199, 1), (2212, 1), (2217, 1), (2219, 1), (2220, 1), (2223, 1), (2231, 1), (2241, 1), (2243, 1), (2278, 1), (2313, 1), (2321, 1), (2322, 2), (2330, 1), (2336, 1), (2339, 2), (2349, 1), (2357, 1), (2395, 1), (2421, 2), (2422, 2), (2454, 1), (2457, 1), (2464, 1), (2506, 1), (2507, 1), (2514, 1), (2556, 1), (2567, 1), (2570, 1), (2599, 2), (2619, 1), (2626, 1), (2673, 1), (2677, 3), (2684, 1), (2701, 1), (2716, 3), (2737, 1), (2746, 1), (2748, 1), (2759, 2), (2803, 2), (2820, 1), (2823, 1), (2841, 2), (2857, 1), (2867, 1), (2900, 1), (2939, 1), (2958, 1), (3021, 1), (3023, 4), (3024, 2), (3043, 1), (3049, 1), (3052, 1), (3074, 1), (309 ...

# %%
print("LDA Model:")
 
for idx in range(NUM_TOPICS):
    # Print the first 10 most representative topics
    print("Topic #%s:" % idx, lda_model.print_topic(idx, 10))
 
print("=" * 20)
 
print("LSI Model:")
 
for idx in range(NUM_TOPICS):
    # Print the first 10 most representative topics
    print("Topic #%s:" % idx, lsi_model.print_topic(idx, 10))
 
print("=" * 20)
# Out:
# LDA Model:
# Topic #0: 0.005*"one" + 0.005*"would" + 0.004*"new" + 0.003*"could" + 0.003*"may" + 0.003*"said" + 0.003*"like" + 0.003*"first" + 0.002*"time" + 0.002*"man"
# Topic #1: 0.006*"one" + 0.004*"could" + 0.003*"would" + 0.003*"said" + 0.003*"new" + 0.003*"like" + 0.002*"man" + 0.002*"also" + 0.002*"time" + 0.002*"first"
# Topic #2: 0.004*"would" + 0.004*"one" + 0.003*"said" + 0.003*"time" + 0.003*"could" + 0.003*"man" + 0.003*"made" + 0.003*"may" + 0.002*"like" + 0.002*"new"
# Topic #3: 0.008*"one" + 0.005*"would" + 0.003*"two" + 0.003*"new" + 0.003*"time" + 0.003*"said" + 0.002*"could" + 0.002*"made" + 0.002*"may" + 0.002*"man"
# Topic #4: 0.005*"would" + 0.004*"one" + 0.003*"man" + 0.003*"could" + 0.003*"said" + 0.003*"two" + 0.002*"time" + 0.002*"first" + 0.002*"new" + 0.002*"may"
# Topic #5: 0.006*"one" + 0.005*"would" + 0.003*"two" + 0.003*"time" + 0.003*"new" + 0.003*"could" + 0.003*"may" + 0.003*"said" + 0.003*"first" + 0.002*"even"
# Topic #6: 0.007*"would" + 0.006*"one" + 0.004*"said" + 0.003*"time" + 0.003*"could" + 0.003*"new" + 0.003*"may" + 0.002*"two" + 0.002*"also" + 0.002*"even"
# Topic #7: 0.008*"one" + 0.005*"would" + 0.005*"said" + 0.004*"could" + 0.003*"time" + 0.003*"first" + 0.003*"years" + 0.003*"man" + 0.002*"may" + 0.002*"two"
# Topic #8: 0.007*"one" + 0.005*"would" + 0.004*"said" + 0.004*"could" + 0.003*"time" + 0.003*"like" + 0.003*"first" + 0.003*"new" + 0.002*"two" + 0.002*"man"
# Topic #9: 0.007*"would" + 0.005*"one" + 0.004*"said" + 0.003*"could" + 0.003*"new" + 0.003*"time" + 0.003*"man" + 0.003*"two" + 0.003*"first" + 0.003*"like"
# ====================
# LSI Model:
# Topic #0: 0.308*"one" + 0.280*"would" + 0.202*"said" + 0.175*"could" + 0.146*"time" + 0.144*"new" + 0.126*"man" + 0.125*"like" + 0.125*"two" + 0.120*"first"
# Topic #1: -0.294*"said" + 0.219*"may" + 0.179*"state" + -0.176*"could" + -0.153*"would" + 0.143*"states" + 0.141*"new" + -0.140*"like" + -0.139*"back" + -0.105*"man"
# Topic #2: -0.340*"said" + -0.338*"state" + 0.228*"one" + -0.191*"states" + -0.161*"year" + -0.152*"mrs." + -0.135*"would" + -0.132*"united" + -0.132*"federal" + -0.130*"government"
# Topic #3: -0.263*"new" + -0.256*"mrs." + 0.154*"feed" + 0.151*"per" + -0.150*"world" + 0.145*"used" + -0.140*"church" + -0.117*"god" + -0.108*"life" + -0.100*"people"
# Topic #4: -0.510*"mrs." + 0.234*"would" + 0.193*"states" + 0.154*"united" + 0.131*"could" + 0.122*"state" + 0.121*"man" + 0.109*"government" + -0.104*"year" + 0.099*"law"
# Topic #5: -0.378*"feed" + 0.371*"would" + -0.275*"per" + -0.244*"state" + -0.127*"god" + -0.127*"daily" + -0.125*"man" + -0.121*"drug" + -0.117*"name" + -0.114*"head"
# Topic #6: 0.274*"feed" + -0.252*"mrs." + 0.222*"per" + 0.178*"would" + 0.174*"school" + -0.161*"state" + -0.158*"states" + -0.138*"one" + 0.135*"said" + -0.134*"united"
# Topic #7: 0.391*"mrs." + 0.278*"would" + -0.257*"state" + -0.232*"school" + -0.225*"said" + 0.216*"feed" + 0.148*"united" + 0.134*"per" + 0.107*"government" + -0.103*"education"
# Topic #8: 0.378*"state" + 0.278*"mrs." + 0.277*"would" + -0.174*"new" + -0.159*"business" + -0.159*"united" + 0.150*"one" + -0.124*"development" + 0.121*"feed" + 0.118*"federal"
# Topic #9: 0.206*"may" + 0.192*"mrs." + -0.191*"new" + 0.180*"shall" + 0.174*"said" + 0.164*"united" + 0.153*"states" + 0.151*"school" + -0.147*"would" + 0.137*"form"
# ====================

# %%
text = "The economy is working better than ever"
bow = dictionary.doc2bow(clean_text(text))
 
print(lsi_model[bow])
 
print(lda_model[bow])
# Out:
# [(0, 0.0916150728946004), (1, -0.00882024847199351), (2, 0.015605852717606932), (3, -0.041374661887419825), (4, -0.016859229611194546), (5, -0.013309474618264558), (6, 0.029697399656179686), (7, -0.019693876663212286), (8, -0.05831659293107751), (9, -0.02626133750787087)]
# [(0, 0.020014111), (1, 0.020013556), (2, 0.020012224), (3, 0.020012833), (4, 0.020013317), (5, 0.020015026), (6, 0.020013805), (7, 0.020013424), (8, 0.81987816), (9, 0.020013575)]

# %%
from gensim import similarities
 
lda_index = similarities.MatrixSimilarity(lda_model[corpus])
 
# Let's perform some queries
similarities = lda_index[lda_model[bow]]
# Sort the similarities
similarities = sorted(enumerate(similarities), key=lambda item: -item[1])
 
# Top most similar documents:
print(similarities[:10])
# [(104, 0.87591344), (178, 0.86124849), (31, 0.8604598), (77, 0.84932965), (85, 0.84843522), (135, 0.84421808), (215, 0.84184396), (353, 0.84038532), (254, 0.83498049), (13, 0.82832891)]
 
# Let's see what's the most similar document
document_id, similarity = similarities[0]
print(data[document_id][:1000])
# Out:
# [(49, 0.9983145), (29, 0.9979101), (162, 0.997615), (391, 0.9975316), (346, 0.99749357), (231, 0.99743426), (460, 0.99743426), (38, 0.99732935), (113, 0.99732935), (114, 0.99732935)]
# The study of the St. Louis area's economic prospects prepared for the Construction Industry Joint Conference confirms and reinforces both the findings of the Metropolitan St. Louis Survey of 1957 and the easily observed picture of the Missouri-Illinois countryside . St. Louis sits in the center of a relatively slow-growing and in some places stagnant mid-continent region . Slackened regional demand for St. Louis goods and services reflects the region's relative lack of purchasing power . Not all St. Louis industries , of course , have a market area confined to the immediate neighborhood . But for those which do , the slow growth of the area has a retarding effect on the metropolitan core . The city has a stake in stimulating growth and purchasing power throughout outstate Missouri and Southern Illinois . Gov. Dalton's New Commerce and Industry Commission is moving to create a nine-state regional group in a collective effort to attract new industry . That is one approach . Another would

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
 
NUM_TOPICS = 10
 
vectorizer = CountVectorizer(min_df=5, max_df=0.9, 
                             stop_words='english', lowercase=True, 
                             token_pattern='[a-zA-Z\-][a-zA-Z\-]{2,}')
data_vectorized = vectorizer.fit_transform(data)
 
# Build a Latent Dirichlet Allocation Model
lda_model = LatentDirichletAllocation(n_components=NUM_TOPICS, max_iter=10, learning_method='online')
lda_Z = lda_model.fit_transform(data_vectorized)
 
text = "The economy is working better than ever"
x = lda_model.transform(vectorizer.transform([text]))[0]
print(x, x.sum())
# Out:
# [0.02500004 0.02500009 0.77496819 0.02500002 0.02500901 0.02500015
#  0.02500156 0.02500411 0.02500587 0.02501094] 1.0
